# %% [markdown]
# ## Description of Notebook
#
# The notebook is used to test ML approach on the VDF statistical momentsa, anisotropies, and particle numbers for species

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
# Out:
# C:\Users\Slava\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# ## Test 1. Some standard classifiers.

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_moments.npy')
labels_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_labels.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_timep.npy')
print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 854
# Among them unstable (positive) samples: 361

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
index_0 = np.where(labels_allmoments == 0)[0]
index_1 = np.where(labels_allmoments == 1)[0]

matplotlib.rcParams.update({'font.size':8})
im, ax = plt.subplots(7, 3, figsize = (10, 18), dpi=150)
for i in range (0, 7, 1):
    for j in range (0, 3, 1):
        hist, bins, patches = ax[i,j].hist(featurevector_allmoments[:,i*3+j], bins=10, alpha=0.00)
        ax[i,j].hist(featurevector_allmoments[index_0,i*3+j], bins=bins, label='Negative samples', alpha=0.50)
        ax[i,j].hist(featurevector_allmoments[index_1,i*3+j], bins=bins, label='Positive samples', alpha=0.50)
        ax[i,j].set(title='Feature '+str(i*3+j))
        ax[i,j].legend()

plt.tight_layout()
plt.show()

# %%
def outputclass_analysis(test_labels, predicted_labels, output_score=''):
    tn, fp, fn, tp = confusion_matrix(test_labels, predicted_labels).ravel()
    print("------------ SUMMARY OF CLASSIFICATION RESULTS ----------------")
    print("TP = "+str(tp))
    print("TN = "+str(tn))
    print("FP = "+str(fp))
    print("FN = "+str(fn))
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    acc = (tp+tn)/(tp+fn+fp+tn)
    tss = tp/(tp+fn) - fp/(fp+tn)
    hss = 2*(tp*tn - fp*fn)/((tp+fn)*(fn+tn) + (tp+fp)*(fp+tn))
    print("Precision = "+str(precision))
    print("Recall = "+str(recall))
    print("Accuracy = "+str(acc))
    print("TSS = "+str(tss))
    print("HSS = "+str(hss))
    if (output_score == 'TSS'): return tss
    if (output_score == 'HSS'): return hss
    if (output_score == 'precision'): return precision
    if (output_score == 'accuracy'): return acc
    return

# %%
X_train, X_test, f_train, f_test = train_test_split(featurevector_allmoments, labels_allmoments, test_size=0.33, random_state=1)

# %% [markdown]
# K-Nearest Neighbor approach (see n_neighbors = 1 case, which is very interesting)

# %%
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 96
# TN = 162
# FP = 3
# FN = 21
# Precision = 0.9696969696969697
# Recall = 0.8205128205128205
# Accuracy = 0.9148936170212766
# TSS = 0.8023310023310023
# HSS = 0.8206962327134001

# %% [markdown]
# An SVM with the weight balancing setup

# %%
clf = SVC(kernel='rbf', class_weight='balanced')
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 100
# TN = 150
# FP = 15
# FN = 17
# Precision = 0.8695652173913043
# Recall = 0.8547008547008547
# Accuracy = 0.8865248226950354
# TSS = 0.7637917637917637
# HSS = 0.7656955912135847

# %% [markdown]
# A very simple neural network with the hidden layer size of 50

# %%
clf = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=10000, tol=1e-6)
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 109
# TN = 161
# FP = 4
# FN = 8
# Precision = 0.9646017699115044
# Recall = 0.9316239316239316
# Accuracy = 0.9574468085106383
# TSS = 0.9073815073815074
# HSS = 0.911916289239419

# %% [markdown]
# ## Test 2. Separation into chunks of data.

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_moments.npy')
labels_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_labels.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_timep.npy')
print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 854
# Among them unstable (positive) samples: 361

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=10000)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
# Out:
# The size of the chunk: 2
# Number of positive - negative samples in train: 181.0 --- 247.0
# Number of positive - negative samples in test: 180.0 --- 246.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 158
# TN = 232
# FP = 14
# FN = 22
# Precision = 0.9186046511627907
# Recall = 0.8777777777777778
# Accuracy = 0.9154929577464789
# TSS = 0.8208672086720867
# HSS = 0.8257906215921483
# The size of the chunk: 4
# Number of positive - negative samples in train: 188.0 --- 240.0
# Number of positive - negative samples in test: 173.0 --- 253.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 157
# TN = 232
# FP = 21
# FN = 16
# Precision = 0.8820224719101124
# Recall = 0.9075144508670521
# Accuracy = 0.9131455399061033
# TSS = 0.8245104982978821
# HSS = 0.8207600809661353
# The size of the chunk: 6
# Number of positive - negative samples in train: 171.0 --- 257.0
# Number of positive - negative samples in test: 190.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 151
# TN = 228
# FP = 8
# FN = 39
# Precision = 0.949685534591195
# Recall = 0.7947368421052632
# Accuracy = 0.8896713615023474
# TSS = 0.7608385370205174
# HSS = 0.7731320959956489
# The size of the chunk: 8
# Number of positive - negative samples in train: 191.0 --- 239.0
# Number of positive - negative samples in test: 170.0 --- 254.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 222
# FP = 32
# FN = 25
# Precision = 0.8192090395480226
# Recall = 0.8529411764705882
# Accuracy = 0.8655660377358491
# TSS = 0.7269569245020843
# HSS = 0.7220407599944795
# The size of the chunk: 10
# Number of positive - negative samples in train: 166.0 --- 264.0
# Number of positive - negative samples in test: 195.0 --- 229.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 146
# TN = 217
# FP = 12
# FN = 49
# Precision = 0.9240506329113924
# Recall = 0.7487179487179487
# Accuracy = 0.8561320754716981
# TSS = 0.6963162019930579
# HSS = 0.7062644800799528
# The size of the chunk: 12
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 139
# TN = 223
# FP = 13
# FN = 47
# Precision = 0.9144736842105263
# Recall = 0.7473118279569892
# Accuracy = 0.8578199052132701
# TSS = 0.6922270821942774
# HSS = 0.7058960182130743
# The size of the chunk: 14
# Number of positive - negative samples in train: 175.0 --- 259.0
# Number of positive - negative samples in test: 186.0 --- 234.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 155
# TN = 200
# FP = 34
# FN = 31
# Precision = 0.8201058201058201
# Recall = 0.8333333333333334
# Accuracy = 0.8452380952380952
# TSS = 0.688034188034188
# HSS = 0.6868978805394991
# The size of the chunk: 16
# Number of positive - negative samples in train: 192.0 --- 240.0
# Number of positive - negative samples in test: 169.0 --- 253.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 146
# TN = 209
# FP = 44
# FN = 23
# Precision = 0.7684210526315789
# Recall = 0.863905325443787
# Accuracy = 0.8412322274881516
# TSS = 0.6899922819655261
# HSS = 0.6760466555145627
# The size of the chunk: 18
# Number of positive - negative samples in train: 163.0 --- 269.0
# Number of positive - negative samples in test: 198.0 --- 224.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 208
# FP = 16
# FN = 53
# Precision = 0.9006211180124224
# Recall = 0.7323232323232324
# Accuracy = 0.8364928909952607
# TSS = 0.660894660894661
# HSS = 0.6681406851906726
# The size of the chunk: 20
# Number of positive - negative samples in train: 176.0 --- 258.0
# Number of positive - negative samples in test: 185.0 --- 235.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 141
# TN = 205
# FP = 30
# FN = 44
# Precision = 0.8245614035087719
# Recall = 0.7621621621621621
# Accuracy = 0.8238095238095238
# TSS = 0.6345025876940771
# HSS = 0.6396521739130435
# The size of the chunk: 22
# Number of positive - negative samples in train: 188.0 --- 248.0
# Number of positive - negative samples in test: 173.0 --- 245.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 134
# TN = 228
# FP = 17
# FN = 39
# Precision = 0.8874172185430463
# Recall = 0.7745664739884393
# Accuracy = 0.8660287081339713
# TSS = 0.7051787188863985
# HSS = 0.7186064962854326
# The size of the chunk: 24
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 107
# TN = 194
# FP = 42
# FN = 79
# Precision = 0.7181208053691275
# Recall = 0.5752688172043011
# Accuracy = 0.7132701421800948
# TSS = 0.3973027155093859
# HSS = 0.4058551115868842
# The size of the chunk: 26
# Number of positive - negative samples in train: 178.0 --- 260.0
# Number of positive - negative samples in test: 183.0 --- 233.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 124
# TN = 188
# FP = 45
# FN = 59
# Precision = 0.7337278106508875
# Recall = 0.6775956284153005
# Accuracy = 0.75
# TSS = 0.4844625812050001
# HSS = 0.48847217952659083
# The size of the chunk: 28
# Number of positive - negative samples in train: 179.0 --- 255.0
# Number of positive - negative samples in test: 182.0 --- 238.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 163
# TN = 193
# FP = 45
# FN = 19
# Precision = 0.7836538461538461
# Recall = 0.8956043956043956
# Accuracy = 0.8476190476190476
# TSS = 0.7065287653522948
# HSS = 0.694850603941513
# The size of the chunk: 30
# Number of positive - negative samples in train: 198.0 --- 236.0
# Number of positive - negative samples in test: 163.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 102
# TN = 214
# FP = 43
# FN = 61
# Precision = 0.7034482758620689
# Recall = 0.6257668711656442
# Accuracy = 0.7523809523809524
# TSS = 0.458451696068368
# HSS = 0.4679010841759045
# The size of the chunk: 32
# Number of positive - negative samples in train: 194.0 --- 244.0
# Number of positive - negative samples in test: 167.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 123
# TN = 232
# FP = 17
# FN = 44
# Precision = 0.8785714285714286
# Recall = 0.7365269461077845
# Accuracy = 0.8533653846153846
# TSS = 0.6682538537383066
# HSS = 0.6865302895543037
# The size of the chunk: 34
# Number of positive - negative samples in train: 147.0 --- 295.0
# Number of positive - negative samples in test: 214.0 --- 198.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 179
# TN = 174
# FP = 24
# FN = 35
# Precision = 0.8817733990147784
# Recall = 0.8364485981308412
# Accuracy = 0.8567961165048543
# TSS = 0.7152364769187199
# HSS = 0.7137541215261423
# The size of the chunk: 36
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 110
# TN = 215
# FP = 21
# FN = 76
# Precision = 0.8396946564885496
# Recall = 0.5913978494623656
# Accuracy = 0.7701421800947867
# TSS = 0.502414798614908
# HSS = 0.5186613673243808
# The size of the chunk: 38
# Number of positive - negative samples in train: 186.0 --- 250.0
# Number of positive - negative samples in test: 175.0 --- 243.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 111
# TN = 206
# FP = 37
# FN = 64
# Precision = 0.75
# Recall = 0.6342857142857142
# Accuracy = 0.7583732057416268
# TSS = 0.48202233980011755
# HSS = 0.4926574855192636
# The size of the chunk: 40
# Number of positive - negative samples in train: 188.0 --- 252.0
# Number of positive - negative samples in test: 173.0 --- 241.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 142
# TN = 181
# FP = 60
# FN = 31
# Precision = 0.7029702970297029
# Recall = 0.8208092485549133
# Accuracy = 0.7801932367149759
# TSS = 0.5718465929532536
# HSS = 0.55863539445629
# The size of the chunk: 42
# Number of positive - negative samples in train: 157.0 --- 277.0
# Number of positive - negative samples in test: 204.0 --- 216.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 166
# FP = 50
# FN = 59
# Precision = 0.7435897435897436
# Recall = 0.7107843137254902
# Accuracy = 0.7404761904761905
# TSS = 0.4793028322440087
# HSS = 0.47989093387866394
# The size of the chunk: 44
# Number of positive - negative samples in train: 190.0 --- 250.0
# Number of positive - negative samples in test: 171.0 --- 243.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 131
# TN = 173
# FP = 70
# FN = 40
# Precision = 0.6517412935323383
# Recall = 0.7660818713450293
# Accuracy = 0.7342995169082126
# TSS = 0.47801602772363005
# HSS = 0.4659066919991556
# The size of the chunk: 46
# Number of positive - negative samples in train: 196.0 --- 244.0
# Number of positive - negative samples in test: 165.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 94
# TN = 179
# FP = 70
# FN = 71
# Precision = 0.573170731707317
# Recall = 0.5696969696969697
# Accuracy = 0.6594202898550725
# TSS = 0.28857247170500183
# HSS = 0.288867772823624
# The size of the chunk: 48
# Number of positive - negative samples in train: 163.0 --- 269.0
# Number of positive - negative samples in test: 198.0 --- 224.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 190
# FP = 34
# FN = 60
# Precision = 0.8023255813953488
# Recall = 0.696969696969697
# Accuracy = 0.7772511848341233
# TSS = 0.5451839826839827
# HSS = 0.5493706547916573
# The size of the chunk: 50
# Number of positive - negative samples in train: 182.0 --- 268.0
# Number of positive - negative samples in test: 179.0 --- 225.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 171
# FP = 54
# FN = 25
# Precision = 0.7403846153846154
# Recall = 0.8603351955307262
# Accuracy = 0.8044554455445545
# TSS = 0.6203351955307262
# HSS = 0.6102291045869767
# The size of the chunk: 52
# Number of positive - negative samples in train: 214.0 --- 224.0
# Number of positive - negative samples in test: 147.0 --- 269.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 122
# TN = 209
# FP = 60
# FN = 25
# Precision = 0.6703296703296703
# Recall = 0.8299319727891157
# Accuracy = 0.7956730769230769
# TSS = 0.6068836456515692
# HSS = 0.5757953836556456
# The size of the chunk: 54
# Number of positive - negative samples in train: 181.0 --- 251.0
# Number of positive - negative samples in test: 180.0 --- 242.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 98
# TN = 164
# FP = 78
# FN = 82
# Precision = 0.5568181818181818
# Recall = 0.5444444444444444
# Accuracy = 0.6208530805687204
# TSS = 0.22213039485766756
# HSS = 0.222764527120361
# The size of the chunk: 56
# Number of positive - negative samples in train: 158.0 --- 290.0
# Number of positive - negative samples in test: 203.0 --- 203.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 113
# TN = 190
# FP = 13
# FN = 90
# Precision = 0.8968253968253969
# Recall = 0.5566502463054187
# Accuracy = 0.7463054187192119
# TSS = 0.4926108374384236
# HSS = 0.49261083743842365
# The size of the chunk: 58
# Number of positive - negative samples in train: 164.0 --- 284.0
# Number of positive - negative samples in test: 197.0 --- 209.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 116
# TN = 198
# FP = 11
# FN = 81
# Precision = 0.9133858267716536
# Recall = 0.5888324873096447
# Accuracy = 0.7733990147783252
# TSS = 0.5362009083622763
# HSS = 0.5417269894240915
# The size of the chunk: 60
# Number of positive - negative samples in train: 196.0 --- 238.0
# Number of positive - negative samples in test: 165.0 --- 255.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 136
# TN = 191
# FP = 64
# FN = 29
# Precision = 0.68
# Recall = 0.8242424242424242
# Accuracy = 0.7785714285714286
# TSS = 0.5732620320855615
# HSS = 0.5525773195876289
# The size of the chunk: 62
# Number of positive - negative samples in train: 228.0 --- 206.0
# Number of positive - negative samples in test: 133.0 --- 287.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 106
# TN = 206
# FP = 81
# FN = 27
# Precision = 0.5668449197860963
# Recall = 0.7969924812030075
# Accuracy = 0.7428571428571429
# TSS = 0.514762516046213
# HSS = 0.46419712254010254
# The size of the chunk: 64
# Number of positive - negative samples in train: 210.0 --- 238.0
# Number of positive - negative samples in test: 151.0 --- 255.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 86
# TN = 225
# FP = 30
# FN = 65
# Precision = 0.7413793103448276
# Recall = 0.5695364238410596
# Accuracy = 0.7660098522167488
# TSS = 0.4518893650175302
# HSS = 0.4743083003952569
# The size of the chunk: 66
# Number of positive - negative samples in train: 178.0 --- 280.0
# Number of positive - negative samples in test: 183.0 --- 213.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 119
# FP = 94
# FN = 38
# Precision = 0.606694560669456
# Recall = 0.7923497267759563
# Accuracy = 0.6666666666666666
# TSS = 0.35103517278534596
# HSS = 0.34362992541249154
# The size of the chunk: 68
# Number of positive - negative samples in train: 145.0 --- 301.0
# Number of positive - negative samples in test: 216.0 --- 192.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 175
# TN = 158
# FP = 34
# FN = 41
# Precision = 0.8373205741626795
# Recall = 0.8101851851851852
# Accuracy = 0.8161764705882353
# TSS = 0.6331018518518519
# HSS = 0.6318221195495235
# The size of the chunk: 70
# Number of positive - negative samples in train: 132.0 --- 302.0
# Number of positive - negative samples in test: 229.0 --- 191.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 88
# TN = 168
# FP = 23
# FN = 141
# Precision = 0.7927927927927928
# Recall = 0.38427947598253276
# Accuracy = 0.6095238095238096
# TSS = 0.2638606278149935
# HSS = 0.2509949761858159
# The size of the chunk: 72
# Number of positive - negative samples in train: 146.0 --- 286.0
# Number of positive - negative samples in test: 215.0 --- 207.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 86
# TN = 161
# FP = 46
# FN = 129
# Precision = 0.6515151515151515
# Recall = 0.4
# Accuracy = 0.5853080568720379
# TSS = 0.1777777777777778
# HSS = 0.17646140464348642
# The size of the chunk: 74
# Number of positive - negative samples in train: 164.0 --- 280.0
# Number of positive - negative samples in test: 197.0 --- 213.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 123
# TN = 118
# FP = 95
# FN = 74
# Precision = 0.5642201834862385
# Recall = 0.6243654822335025
# Accuracy = 0.5878048780487805
# TSS = 0.17835609256214102
# HSS = 0.17764485271428232
# The size of the chunk: 76
# Number of positive - negative samples in train: 181.0 --- 275.0
# Number of positive - negative samples in test: 180.0 --- 218.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 117
# TN = 177
# FP = 41
# FN = 63
# Precision = 0.740506329113924
# Recall = 0.65
# Accuracy = 0.7386934673366834
# TSS = 0.4619266055045872
# HSS = 0.466900211220442
# The size of the chunk: 78
# Number of positive - negative samples in train: 203.0 --- 261.0
# Number of positive - negative samples in test: 158.0 --- 232.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 144
# FP = 88
# FN = 40
# Precision = 0.5728155339805825
# Recall = 0.7468354430379747
# Accuracy = 0.6717948717948717
# TSS = 0.3675250982103885
# HSS = 0.350541215653622
# The size of the chunk: 80
# Number of positive - negative samples in train: 210.0 --- 244.0
# Number of positive - negative samples in test: 151.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 128
# TN = 190
# FP = 59
# FN = 23
# Precision = 0.6844919786096256
# Recall = 0.847682119205298
# Accuracy = 0.795
# TSS = 0.6107343280406394
# HSS = 0.58336508904301
# The size of the chunk: 82
# Number of positive - negative samples in train: 198.0 --- 246.0
# Number of positive - negative samples in test: 163.0 --- 247.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 107
# TN = 184
# FP = 63
# FN = 56
# Precision = 0.6294117647058823
# Recall = 0.656441717791411
# Accuracy = 0.7097560975609756
# TSS = 0.40138098904647174
# HSS = 0.39847121193441004
# The size of the chunk: 84
# Number of positive - negative samples in train: 192.0 --- 242.0
# Number of positive - negative samples in test: 169.0 --- 251.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 88
# TN = 173
# FP = 78
# FN = 81
# Precision = 0.5301204819277109
# Recall = 0.5207100591715976
# Accuracy = 0.6214285714285714
# TSS = 0.20995308706004384
# HSS = 0.21056364668053718
# The size of the chunk: 86
# Number of positive - negative samples in train: 194.0 --- 236.0
# Number of positive - negative samples in test: 167.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 79
# TN = 151
# FP = 106
# FN = 88
# Precision = 0.42702702702702705
# Recall = 0.47305389221556887
# Accuracy = 0.5424528301886793
# TSS = 0.060602530347864614
# HSS = 0.05947997896133001
# The size of the chunk: 88
# Number of positive - negative samples in train: 195.0 --- 245.0
# Number of positive - negative samples in test: 166.0 --- 248.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 79
# TN = 172
# FP = 76
# FN = 87
# Precision = 0.5096774193548387
# Recall = 0.4759036144578313
# Accuracy = 0.606280193236715
# TSS = 0.1694520015546055
# HSS = 0.17132892894859642
# The size of the chunk: 90
# Number of positive - negative samples in train: 195.0 --- 255.0
# Number of positive - negative samples in test: 166.0 --- 238.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 98
# TN = 175
# FP = 63
# FN = 68
# Precision = 0.6086956521739131
# Recall = 0.5903614457831325
# Accuracy = 0.6757425742574258
# TSS = 0.32565556343019136
# HSS = 0.3271460537021969
# The size of the chunk: 92
# Number of positive - negative samples in train: 206.0 --- 254.0
# Number of positive - negative samples in test: 155.0 --- 239.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 128
# FP = 111
# FN = 37
# Precision = 0.5152838427947598
# Recall = 0.7612903225806451
# Accuracy = 0.6243654822335025
# TSS = 0.29685517613713047
# HSS = 0.2738774188728115
# The size of the chunk: 94
# Number of positive - negative samples in train: 212.0 --- 258.0
# Number of positive - negative samples in test: 149.0 --- 235.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 113
# TN = 113
# FP = 122
# FN = 36
# Precision = 0.4808510638297872
# Recall = 0.7583892617449665
# Accuracy = 0.5885416666666666
# TSS = 0.23924032557475372
# HSS = 0.21638726009350864
# The size of the chunk: 96
# Number of positive - negative samples in train: 221.0 --- 249.0
# Number of positive - negative samples in test: 140.0 --- 244.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 123
# TN = 114
# FP = 130
# FN = 17
# Precision = 0.48616600790513836
# Recall = 0.8785714285714286
# Accuracy = 0.6171875
# TSS = 0.3457845433255269
# HSS = 0.29503446897791985
# The size of the chunk: 98
# Number of positive - negative samples in train: 226.0 --- 236.0
# Number of positive - negative samples in test: 135.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 127
# TN = 189
# FP = 68
# FN = 8
# Precision = 0.6512820512820513
# Recall = 0.9407407407407408
# Accuracy = 0.8061224489795918
# TSS = 0.6761493010520248
# HSS = 0.6116282101420936
# The size of the chunk: 100
# Number of positive - negative samples in train: 218.0 --- 236.0
# Number of positive - negative samples in test: 143.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 108
# FP = 149
# FN = 5
# Precision = 0.4808362369337979
# Recall = 0.965034965034965
# Accuracy = 0.615
# TSS = 0.3852684280699844
# HSS = 0.3149313819257546

# %%
im, ax = plt.subplots(1, 1, figsize=(6,5), dpi=120)
ax.plot(chunksizes, output_scores)
ax.set(xlim=[0.0,105.0], ylim=[0.5,1.0], xlabel='Size of the chunk, # samples', ylabel='Accuracy', \
       title='Classifier: Neural Network (1 hidden layer, 50 nodes)')
plt.tight_layout()
plt.show()

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = SVC(kernel='rbf', class_weight='balanced')
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
# Out:
# The size of the chunk: 2
# Number of positive - negative samples in train: 181.0 --- 247.0
# Number of positive - negative samples in test: 180.0 --- 246.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 157
# TN = 206
# FP = 40
# FN = 23
# Precision = 0.7969543147208121
# Recall = 0.8722222222222222
# Accuracy = 0.852112676056338
# TSS = 0.7096205962059621
# HSS = 0.700742623937914
# The size of the chunk: 4
# Number of positive - negative samples in train: 188.0 --- 240.0
# Number of positive - negative samples in test: 173.0 --- 253.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 155
# TN = 221
# FP = 32
# FN = 18
# Precision = 0.8288770053475936
# Recall = 0.8959537572254336
# Accuracy = 0.8826291079812206
# TSS = 0.7694715437866984
# HSS = 0.759750953100679
# The size of the chunk: 6
# Number of positive - negative samples in train: 171.0 --- 257.0
# Number of positive - negative samples in test: 190.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 164
# TN = 204
# FP = 32
# FN = 26
# Precision = 0.8367346938775511
# Recall = 0.8631578947368421
# Accuracy = 0.863849765258216
# TSS = 0.7275646743978591
# HSS = 0.7253323847214194
# The size of the chunk: 8
# Number of positive - negative samples in train: 191.0 --- 239.0
# Number of positive - negative samples in test: 170.0 --- 254.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 141
# TN = 210
# FP = 44
# FN = 29
# Precision = 0.7621621621621621
# Recall = 0.8294117647058824
# Accuracy = 0.8278301886792453
# TSS = 0.6561834182491895
# HSS = 0.6467473179639351
# The size of the chunk: 10
# Number of positive - negative samples in train: 166.0 --- 264.0
# Number of positive - negative samples in test: 195.0 --- 229.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 152
# TN = 209
# FP = 20
# FN = 43
# Precision = 0.8837209302325582
# Recall = 0.7794871794871795
# Accuracy = 0.8514150943396226
# TSS = 0.6921509349456948
# HSS = 0.6982649557202241
# The size of the chunk: 12
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 142
# TN = 218
# FP = 18
# FN = 44
# Precision = 0.8875
# Recall = 0.7634408602150538
# Accuracy = 0.8530805687203792
# TSS = 0.6871696737743758
# HSS = 0.6974980345003006
# The size of the chunk: 14
# Number of positive - negative samples in train: 175.0 --- 259.0
# Number of positive - negative samples in test: 186.0 --- 234.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 158
# TN = 192
# FP = 42
# FN = 28
# Precision = 0.79
# Recall = 0.8494623655913979
# Accuracy = 0.8333333333333334
# TSS = 0.6699751861042184
# HSS = 0.66484268125855
# The size of the chunk: 16
# Number of positive - negative samples in train: 192.0 --- 240.0
# Number of positive - negative samples in test: 169.0 --- 253.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 147
# TN = 210
# FP = 43
# FN = 22
# Precision = 0.7736842105263158
# Recall = 0.8698224852071006
# Accuracy = 0.8459715639810427
# TSS = 0.6998620108988002
# HSS = 0.6857169046036802
# The size of the chunk: 18
# Number of positive - negative samples in train: 163.0 --- 269.0
# Number of positive - negative samples in test: 198.0 --- 224.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 127
# TN = 201
# FP = 23
# FN = 71
# Precision = 0.8466666666666667
# Recall = 0.6414141414141414
# Accuracy = 0.7772511848341233
# TSS = 0.53873556998557
# HSS = 0.5464233443102817
# The size of the chunk: 20
# Number of positive - negative samples in train: 176.0 --- 258.0
# Number of positive - negative samples in test: 185.0 --- 235.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 131
# TN = 192
# FP = 43
# FN = 54
# Precision = 0.7528735632183908
# Recall = 0.7081081081081081
# Accuracy = 0.7690476190476191
# TSS = 0.5251293847038527
# HSS = 0.5284722222222222
# The size of the chunk: 22
# Number of positive - negative samples in train: 188.0 --- 248.0
# Number of positive - negative samples in test: 173.0 --- 245.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 123
# TN = 213
# FP = 32
# FN = 50
# Precision = 0.7935483870967742
# Recall = 0.7109826589595376
# Accuracy = 0.8038277511961722
# TSS = 0.5803704140615784
# HSS = 0.5893811246615712
# The size of the chunk: 24
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 103
# TN = 172
# FP = 64
# FN = 83
# Precision = 0.6167664670658682
# Recall = 0.553763440860215
# Accuracy = 0.6516587677725119
# TSS = 0.2825770001822489
# HSS = 0.285668225052394
# The size of the chunk: 26
# Number of positive - negative samples in train: 178.0 --- 260.0
# Number of positive - negative samples in test: 183.0 --- 233.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 101
# TN = 200
# FP = 33
# FN = 82
# Precision = 0.753731343283582
# Recall = 0.5519125683060109
# Accuracy = 0.7235576923076923
# TSS = 0.41028166701845725
# HSS = 0.42241753996233156
# The size of the chunk: 28
# Number of positive - negative samples in train: 179.0 --- 255.0
# Number of positive - negative samples in test: 182.0 --- 238.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 195
# FP = 43
# FN = 22
# Precision = 0.7881773399014779
# Recall = 0.8791208791208791
# Accuracy = 0.8452380952380952
# TSS = 0.6984486102133161
# HSS = 0.689094387755102
# The size of the chunk: 30
# Number of positive - negative samples in train: 198.0 --- 236.0
# Number of positive - negative samples in test: 163.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 109
# TN = 203
# FP = 54
# FN = 54
# Precision = 0.6687116564417178
# Recall = 0.6687116564417178
# Accuracy = 0.7428571428571429
# TSS = 0.45859492492420806
# HSS = 0.45859492492420806
# The size of the chunk: 32
# Number of positive - negative samples in train: 194.0 --- 244.0
# Number of positive - negative samples in test: 167.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 128
# TN = 230
# FP = 19
# FN = 39
# Precision = 0.8707482993197279
# Recall = 0.7664670658682635
# Accuracy = 0.8605769230769231
# TSS = 0.6901618449847293
# HSS = 0.7040453352304786
# The size of the chunk: 34
# Number of positive - negative samples in train: 147.0 --- 295.0
# Number of positive - negative samples in test: 214.0 --- 198.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 191
# TN = 155
# FP = 43
# FN = 23
# Precision = 0.8162393162393162
# Recall = 0.8925233644859814
# Accuracy = 0.8398058252427184
# TSS = 0.6753516473142642
# HSS = 0.6779114943617929
# The size of the chunk: 36
# Number of positive - negative samples in train: 175.0 --- 257.0
# Number of positive - negative samples in test: 186.0 --- 236.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 100
# TN = 196
# FP = 40
# FN = 86
# Precision = 0.7142857142857143
# Recall = 0.5376344086021505
# Accuracy = 0.7014218009478673
# TSS = 0.3681428831784217
# HSS = 0.37804706873157723
# The size of the chunk: 38
# Number of positive - negative samples in train: 186.0 --- 250.0
# Number of positive - negative samples in test: 175.0 --- 243.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 123
# TN = 195
# FP = 48
# FN = 52
# Precision = 0.7192982456140351
# Recall = 0.7028571428571428
# Accuracy = 0.7607655502392344
# TSS = 0.505326278659612
# HSS = 0.5069475571492604
# The size of the chunk: 40
# Number of positive - negative samples in train: 188.0 --- 252.0
# Number of positive - negative samples in test: 173.0 --- 241.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 116
# TN = 146
# FP = 95
# FN = 57
# Precision = 0.5497630331753555
# Recall = 0.6705202312138728
# Accuracy = 0.6328502415458938
# TSS = 0.27632935984457824
# HSS = 0.2680237292078632
# The size of the chunk: 42
# Number of positive - negative samples in train: 157.0 --- 277.0
# Number of positive - negative samples in test: 204.0 --- 216.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 143
# TN = 161
# FP = 55
# FN = 61
# Precision = 0.7222222222222222
# Recall = 0.7009803921568627
# Accuracy = 0.7238095238095238
# TSS = 0.44635076252723305
# HSS = 0.4467157263559553
# The size of the chunk: 44
# Number of positive - negative samples in train: 190.0 --- 250.0
# Number of positive - negative samples in test: 171.0 --- 243.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 103
# TN = 186
# FP = 57
# FN = 68
# Precision = 0.64375
# Recall = 0.6023391812865497
# Accuracy = 0.6980676328502415
# TSS = 0.36777128005198184
# HSS = 0.3713098622348568
# The size of the chunk: 46
# Number of positive - negative samples in train: 196.0 --- 244.0
# Number of positive - negative samples in test: 165.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 61
# TN = 207
# FP = 42
# FN = 104
# Precision = 0.5922330097087378
# Recall = 0.3696969696969697
# Accuracy = 0.6473429951690821
# TSS = 0.20102227090178898
# HSS = 0.2146253995478288
# The size of the chunk: 48
# Number of positive - negative samples in train: 163.0 --- 269.0
# Number of positive - negative samples in test: 198.0 --- 224.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 148
# TN = 146
# FP = 78
# FN = 50
# Precision = 0.6548672566371682
# Recall = 0.7474747474747475
# Accuracy = 0.6966824644549763
# TSS = 0.3992604617604618
# HSS = 0.39601037659898025
# The size of the chunk: 50
# Number of positive - negative samples in train: 182.0 --- 268.0
# Number of positive - negative samples in test: 179.0 --- 225.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 158
# TN = 148
# FP = 77
# FN = 21
# Precision = 0.6723404255319149
# Recall = 0.88268156424581
# Accuracy = 0.7574257425742574
# TSS = 0.5404593420235878
# HSS = 0.5237109929504608
# The size of the chunk: 52
# Number of positive - negative samples in train: 214.0 --- 224.0
# Number of positive - negative samples in test: 147.0 --- 269.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 91
# TN = 163
# FP = 106
# FN = 56
# Precision = 0.4619289340101523
# Recall = 0.6190476190476191
# Accuracy = 0.6105769230769231
# TSS = 0.22499557443795365
# HSS = 0.20888408893480148
# The size of the chunk: 54
# Number of positive - negative samples in train: 181.0 --- 251.0
# Number of positive - negative samples in test: 180.0 --- 242.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 92
# TN = 192
# FP = 50
# FN = 88
# Precision = 0.647887323943662
# Recall = 0.5111111111111111
# Accuracy = 0.6729857819905213
# TSS = 0.3044995408631772
# HSS = 0.31296305035156435
# The size of the chunk: 56
# Number of positive - negative samples in train: 158.0 --- 290.0
# Number of positive - negative samples in test: 203.0 --- 203.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 91
# TN = 188
# FP = 15
# FN = 112
# Precision = 0.8584905660377359
# Recall = 0.4482758620689655
# Accuracy = 0.687192118226601
# TSS = 0.37438423645320196
# HSS = 0.37438423645320196
# The size of the chunk: 58
# Number of positive - negative samples in train: 164.0 --- 284.0
# Number of positive - negative samples in test: 197.0 --- 209.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 99
# TN = 178
# FP = 31
# FN = 98
# Precision = 0.7615384615384615
# Recall = 0.5025380710659898
# Accuracy = 0.6822660098522167
# TSS = 0.35421271221431516
# HSS = 0.35770523165975815
# The size of the chunk: 60
# Number of positive - negative samples in train: 196.0 --- 238.0
# Number of positive - negative samples in test: 165.0 --- 255.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 127
# TN = 219
# FP = 36
# FN = 38
# Precision = 0.7791411042944786
# Recall = 0.7696969696969697
# Accuracy = 0.8238095238095238
# TSS = 0.6285204991087343
# HSS = 0.6298678099321187
# The size of the chunk: 62
# Number of positive - negative samples in train: 228.0 --- 206.0
# Number of positive - negative samples in test: 133.0 --- 287.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 119
# TN = 132
# FP = 155
# FN = 14
# Precision = 0.4343065693430657
# Recall = 0.8947368421052632
# Accuracy = 0.5976190476190476
# TSS = 0.35466715569411333
# HSS = 0.2761279268989149
# The size of the chunk: 64
# Number of positive - negative samples in train: 210.0 --- 238.0
# Number of positive - negative samples in test: 151.0 --- 255.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 108
# TN = 155
# FP = 100
# FN = 43
# Precision = 0.5192307692307693
# Recall = 0.7152317880794702
# Accuracy = 0.6477832512315271
# TSS = 0.32307492533437215
# HSS = 0.29998311992090476
# The size of the chunk: 66
# Number of positive - negative samples in train: 178.0 --- 280.0
# Number of positive - negative samples in test: 183.0 --- 213.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 135
# TN = 120
# FP = 93
# FN = 48
# Precision = 0.5921052631578947
# Recall = 0.7377049180327869
# Accuracy = 0.6439393939393939
# TSS = 0.3010851997229278
# HSS = 0.2959600544711757
# The size of the chunk: 68
# Number of positive - negative samples in train: 145.0 --- 301.0
# Number of positive - negative samples in test: 216.0 --- 192.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 174
# TN = 74
# FP = 118
# FN = 42
# Precision = 0.5958904109589042
# Recall = 0.8055555555555556
# Accuracy = 0.6078431372549019
# TSS = 0.1909722222222222
# HSS = 0.1952662721893491
# The size of the chunk: 70
# Number of positive - negative samples in train: 132.0 --- 302.0
# Number of positive - negative samples in test: 229.0 --- 191.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 77
# TN = 115
# FP = 76
# FN = 152
# Precision = 0.5032679738562091
# Recall = 0.33624454148471616
# Accuracy = 0.45714285714285713
# TSS = -0.061661217677587477
# HSS = -0.059690591594183655
# The size of the chunk: 72
# Number of positive - negative samples in train: 146.0 --- 286.0
# Number of positive - negative samples in test: 215.0 --- 207.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 72
# TN = 98
# FP = 109
# FN = 143
# Precision = 0.39779005524861877
# Recall = 0.33488372093023255
# Accuracy = 0.4028436018957346
# TSS = -0.1916863273789462
# HSS = -0.1911023498577541
# The size of the chunk: 74
# Number of positive - negative samples in train: 164.0 --- 280.0
# Number of positive - negative samples in test: 197.0 --- 213.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 88
# TN = 79
# FP = 134
# FN = 109
# Precision = 0.3963963963963964
# Recall = 0.4467005076142132
# Accuracy = 0.4073170731707317
# TSS = -0.18240747360644405
# HSS = -0.18154218353454615
# The size of the chunk: 76
# Number of positive - negative samples in train: 181.0 --- 275.0
# Number of positive - negative samples in test: 180.0 --- 218.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 110
# TN = 125
# FP = 93
# FN = 70
# Precision = 0.541871921182266
# Recall = 0.6111111111111112
# Accuracy = 0.5904522613065326
# TSS = 0.1845056065239552
# HSS = 0.18247347329687225
# The size of the chunk: 78
# Number of positive - negative samples in train: 203.0 --- 261.0
# Number of positive - negative samples in test: 158.0 --- 232.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 125
# TN = 158
# FP = 74
# FN = 33
# Precision = 0.628140703517588
# Recall = 0.7911392405063291
# Accuracy = 0.7256410256410256
# TSS = 0.4721737232649498
# HSS = 0.45340947790323005
# The size of the chunk: 80
# Number of positive - negative samples in train: 210.0 --- 244.0
# Number of positive - negative samples in test: 151.0 --- 249.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 143
# FP = 106
# FN = 13
# Precision = 0.5655737704918032
# Recall = 0.9139072847682119
# Accuracy = 0.7025
# TSS = 0.488204473523232
# HSS = 0.43543030648069075
# The size of the chunk: 82
# Number of positive - negative samples in train: 198.0 --- 246.0
# Number of positive - negative samples in test: 163.0 --- 247.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 124
# TN = 159
# FP = 88
# FN = 39
# Precision = 0.5849056603773585
# Recall = 0.7607361963190185
# Accuracy = 0.6902439024390243
# TSS = 0.4044608926752938
# HSS = 0.3847917011271533
# The size of the chunk: 84
# Number of positive - negative samples in train: 192.0 --- 242.0
# Number of positive - negative samples in test: 169.0 --- 251.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 71
# TN = 171
# FP = 80
# FN = 98
# Precision = 0.47019867549668876
# Recall = 0.42011834319526625
# Accuracy = 0.5761904761904761
# TSS = 0.10139324359367263
# HSS = 0.1031885031549147
# The size of the chunk: 86
# Number of positive - negative samples in train: 194.0 --- 236.0
# Number of positive - negative samples in test: 167.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 61
# TN = 179
# FP = 78
# FN = 106
# Precision = 0.43884892086330934
# Recall = 0.3652694610778443
# Accuracy = 0.5660377358490566
# TSS = 0.0617675155525525
# HSS = 0.06363570897045057
# The size of the chunk: 88
# Number of positive - negative samples in train: 195.0 --- 245.0
# Number of positive - negative samples in test: 166.0 --- 248.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 108
# TN = 158
# FP = 90
# FN = 58
# Precision = 0.5454545454545454
# Recall = 0.6506024096385542
# Accuracy = 0.642512077294686
# TSS = 0.2876991838321026
# HSS = 0.2788135593220339
# The size of the chunk: 90
# Number of positive - negative samples in train: 195.0 --- 255.0
# Number of positive - negative samples in test: 166.0 --- 238.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 128
# TN = 153
# FP = 85
# FN = 38
# Precision = 0.6009389671361502
# Recall = 0.7710843373493976
# Accuracy = 0.6955445544554455
# TSS = 0.4139414802065405
# HSS = 0.39694174757281553
# The size of the chunk: 92
# Number of positive - negative samples in train: 206.0 --- 254.0
# Number of positive - negative samples in test: 155.0 --- 239.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 140
# TN = 117
# FP = 122
# FN = 15
# Precision = 0.5343511450381679
# Recall = 0.9032258064516129
# Accuracy = 0.6522842639593909
# TSS = 0.3927655554055878
# HSS = 0.35027323719877707
# The size of the chunk: 94
# Number of positive - negative samples in train: 212.0 --- 258.0
# Number of positive - negative samples in test: 149.0 --- 235.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 139
# TN = 110
# FP = 125
# FN = 10
# Precision = 0.5265151515151515
# Recall = 0.9328859060402684
# Accuracy = 0.6484375
# TSS = 0.4009710124232472
# HSS = 0.35135135135135137
# The size of the chunk: 96
# Number of positive - negative samples in train: 221.0 --- 249.0
# Number of positive - negative samples in test: 140.0 --- 244.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 134
# TN = 81
# FP = 163
# FN = 6
# Precision = 0.4511784511784512
# Recall = 0.9571428571428572
# Accuracy = 0.5598958333333334
# TSS = 0.28911007025761126
# HSS = 0.23334278423589452
# The size of the chunk: 98
# Number of positive - negative samples in train: 226.0 --- 236.0
# Number of positive - negative samples in test: 135.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 129
# TN = 92
# FP = 165
# FN = 6
# Precision = 0.4387755102040816
# Recall = 0.9555555555555556
# Accuracy = 0.5637755102040817
# TSS = 0.3135322092520536
# HSS = 0.24503311258278146
# The size of the chunk: 100
# Number of positive - negative samples in train: 218.0 --- 236.0
# Number of positive - negative samples in test: 143.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 137
# TN = 103
# FP = 154
# FN = 6
# Precision = 0.47079037800687284
# Recall = 0.958041958041958
# Accuracy = 0.6
# TSS = 0.35882016815868956
# HSS = 0.2918317215128245

# %%
im, ax = plt.subplots(1, 1, figsize=(6,5), dpi=120)
ax.plot(chunksizes, output_scores)
ax.set(xlim=[0.0,105.0], ylim=[0.5,1.0], xlabel='Size of the chunk, # samples', ylabel='Accuracy', \
       title=r'Classifier: SVM RBF (default C and $\gamma$)')
plt.tight_layout()
plt.show()

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = SVC(kernel='rbf', class_weight='balanced')
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
