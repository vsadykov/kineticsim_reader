# %% [markdown]
# ## Description of Notebook
#
# The notebook is used to test ML approach on the VDF statistical momenta, anisotropies, and particle fraction numbers

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, ShuffleSplit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def outputclass_analysis(test_labels, predicted_labels, output_score=''):
    tn, fp, fn, tp = confusion_matrix(test_labels, predicted_labels).ravel()
    print("------------ SUMMARY OF CLASSIFICATION RESULTS ----------------")
    print("TP = "+str(tp))
    print("TN = "+str(tn))
    print("FP = "+str(fp))
    print("FN = "+str(fn))
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    acc = (tp+tn)/(tp+fn+fp+tn)
    tss = tp/(tp+fn) - fp/(fp+tn)
    hss = 2*(tp*tn - fp*fn)/((tp+fn)*(fn+tn) + (tp+fp)*(fp+tn))
    print("Precision = "+str(precision))
    print("Recall = "+str(recall))
    print("Accuracy = "+str(acc))
    print("TSS = "+str(tss))
    print("HSS = "+str(hss))
    if (output_score == 'TSS'): return tss
    if (output_score == 'HSS'): return hss
    if (output_score == 'precision'): return precision
    if (output_score == 'accuracy'): return acc
    return

def outputclass_analysis_scorereturn(test_labels, predicted_labels):
    tn, fp, fn, tp = confusion_matrix(test_labels, predicted_labels).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    acc = (tp+tn)/(tp+fn+fp+tn)
    tss = tp/(tp+fn) - fp/(fp+tn)
    hss = 2*(tp*tn - fp*fn)/((tp+fn)*(fn+tn) + (tp+fp)*(fp+tn))
    return tp, tn, fp, fn, acc, tss

# %% [markdown]
# ## Test 1. Preparation and testing of the data set (thres 0.001, unified labels, random split).
#
# We have previously determined that the threshold of 0.001 provides the most reasonably-partitioned data set in case the labels for magnetic energy evolution and anisotropies are unified. The new elements here will be hyperparameter tuning for ML.

# %% [markdown]
# First, we load the data set, normalize it, and do some visualizations

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.featurevector_allmoments_all.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.timep_array_all.npy')
labels_an = np.load('./mldata_vdfmoments/allsimulations.labels_allmoments_an_01_all.npy')
labels_me = np.load('./mldata_vdfmoments/allsimulations.labels_allmoments_me_01_all.npy')
# merging both labels
labels_allmoments = np.copy(labels_me)
labels_allmoments[np.where(labels_an == 1)] = 1

print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 1253
# Among them unstable (positive) samples: 398

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
index_0 = np.where(labels_allmoments == 0)[0]
index_1 = np.where(labels_allmoments == 1)[0]

matplotlib.rcParams.update({'font.size':8})
im, ax = plt.subplots(7, 3, figsize = (10, 18), dpi=150)
for i in range (0, 7, 1):
    for j in range (0, 3, 1):
        if ((i == 6) and (j == 2)): continue
        hist, bins, patches = ax[i,j].hist(featurevector_allmoments[:,i*3+j], bins=10, alpha=0.00)
        ax[i,j].hist(featurevector_allmoments[index_0,i*3+j], bins=bins, label='Negative samples', alpha=0.50)
        ax[i,j].hist(featurevector_allmoments[index_1,i*3+j], bins=bins, label='Positive samples', alpha=0.50)
        ax[i,j].set(title='Feature '+str(i*3+j+1))
        ax[i,j].legend()

plt.tight_layout()
plt.show()

# %%
data_split = ShuffleSplit(n_splits=10, test_size=0.33, random_state=0)

# %%
data_split.split(labels_allmoments)
# Out:
# <generator object BaseShuffleSplit.split at 0x0000021E2840C5F0>

# %% [markdown]
# Next, we introduce the grid search procedure to determined the optimal parameters for the machine learning. The data set will be split according to the data_split function defined above. The parameters to test are different for different models, and therefore the dictionaries are defined differently.

# %% [markdown]
# ### Case 1. kNN classifier.

# %%
# parameter grid
param_grid = {'n_neighbors': [2, 5, 10, 25], \
              'p': [1, 2]}

# classifier and gridsearch
clf = KNeighborsClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=data_split, verbose=0)
grid_search.fit(featurevector_allmoments, labels_allmoments)
print("Best parameters found: ", grid_search.best_params_)
best_params = grid_search.best_params_

# fitting 10 times and accumulating the scores for the best model
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i, split_indexes in enumerate(data_split.split(featurevector_allmoments)):
    train_index, test_index = split_indexes
    X_train, X_test = featurevector_allmoments[train_index], featurevector_allmoments[test_index]
    f_train, f_test = labels_allmoments[train_index], labels_allmoments[test_index]
    clf = KNeighborsClassifier(**best_params)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=2, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=1; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END .................................n_neighbors=5, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=10, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=1; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# [CV] END ................................n_neighbors=25, p=2; total time=   0.0s
# Best parameters found:  {'n_neighbors': 5, 'p': 1}
# TP = 106.5+/-7.269800547470337
# TN = 269.1+/-9.159148432032314
# FP = 12.8+/-4.707440918375928
# FN = 25.6+/-4.431703961232067
# Acc = 0.9072463768115941+/-0.012926655227304032
# TSS = 0.7610876491499026+/-0.03054606968046167

# %% [markdown]
# ### Case 2. Support vector classifier with RBF kernel

# %%
# parameter grid
param_grid = {'kernel': ['rbf'], \
              'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0], \
              'gamma': [0.0001, 0.001, 0.01, 0.1, 1.0, 'scale'], \
              'class_weight': [None, 'balanced']}

# classifier and gridsearch
clf = SVC()
grid_search = GridSearchCV(clf, param_grid, cv=data_split, verbose=0)
grid_search.fit(featurevector_allmoments, labels_allmoments)
print("Best parameters found: ", grid_search.best_params_)
best_params = grid_search.best_params_

# fitting 10 times and accumulating the scores for the best model
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i, split_indexes in enumerate(data_split.split(featurevector_allmoments)):
    train_index, test_index = split_indexes
    X_train, X_test = featurevector_allmoments[train_index], featurevector_allmoments[test_index]
    f_train, f_test = labels_allmoments[train_index], labels_allmoments[test_index]
    clf = SVC(**best_params)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .C=0.001, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.001, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.01, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.01, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.01, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.01, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=0.1, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=0.1, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=0.1, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=1.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=1.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ....C=1.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..C=1.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..C=10.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END ...C=10.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .C=10.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# ...
# [CV] END C=1000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=1000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=1.0, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END C=10000.0, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.0s
# Best parameters found:  {'C': 10000.0, 'class_weight': None, 'gamma': 0.01, 'kernel': 'rbf'}
# TP = 113.8+/-6.896375859826668
# TN = 267.8+/-9.410632284814874
# FP = 14.1+/-4.2296571965113205
# FN = 18.3+/-4.775981574503822
# Acc = 0.9217391304347826+/-0.01409270738726071
# TSS = 0.8121584969254627+/-0.033483703585796325

# %% [markdown]
# ### Case 3. Random Forest

# %%
# parameter grid
param_grid = {'n_estimators': [10,50,100,200], \
              'max_depth': [None, 2, 5, 10, 25], \
              'class_weight': [None, 'balanced']}

# classifier and gridsearch
clf = RandomForestClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=data_split, verbose=0)
grid_search.fit(featurevector_allmoments, labels_allmoments)
print("Best parameters found: ", grid_search.best_params_)
best_params = grid_search.best_params_

# fitting 10 times and accumulating the scores for the best model
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i, split_indexes in enumerate(data_split.split(featurevector_allmoments)):
    train_index, test_index = split_indexes
    X_train, X_test = featurevector_allmoments[train_index], featurevector_allmoments[test_index]
    f_train, f_test = labels_allmoments[train_index], labels_allmoments[test_index]
    clf = RandomForestClassifier(**best_params)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END .class_weight=None, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.3s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.5s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=None, max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....class_weight=None, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END ...class_weight=None, max_depth=5, n_estimators=200; total time=   0.6s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.5s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ...class_weight=None, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.3s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=100; total time=   0.2s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END ..class_weight=None, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, n_estimators=200; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=5, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=10; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=50; total time=   0.0s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=100; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=25, n_estimators=200; total time=   0.4s
# Best parameters found:  {'class_weight': None, 'max_depth': 10, 'n_estimators': 100}
# TP = 121.9+/-7.7
# TN = 276.1+/-8.055432949258531
# FP = 5.8+/-1.661324772583615
# FN = 10.2+/-2.9597297173897483
# Acc = 0.961352657004831+/-0.006570758699872175
# TSS = 0.9024732463752805+/-0.020276684760218863

# %% [markdown]
# ### Case 4. Neural Networks

# %%
# parameter grid
param_grid = {'hidden_layer_sizes': [(10,), (50,), (200,), (500,)], \
              'max_iter': [10000]}

# classifier and gridsearch
clf = MLPClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=data_split, verbose=0)
grid_search.fit(featurevector_allmoments, labels_allmoments)
print("Best parameters found: ", grid_search.best_params_)
best_params = grid_search.best_params_

# fitting 10 times and accumulating the scores for the best model
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i, split_indexes in enumerate(data_split.split(featurevector_allmoments)):
    train_index, test_index = split_indexes
    X_train, X_test = featurevector_allmoments[train_index], featurevector_allmoments[test_index]
    f_train, f_test = labels_allmoments[train_index], labels_allmoments[test_index]
    clf = MLPClassifier(**best_params)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   2.0s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   3.5s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   2.8s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   2.3s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   3.3s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   2.2s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   1.7s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   1.3s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   2.0s
# [CV] END ...........hidden_layer_sizes=(10,), max_iter=10000; total time=   1.8s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.6s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.5s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.1s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.3s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   4.3s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   2.8s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   4.1s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   2.6s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.1s
# [CV] END ...........hidden_layer_sizes=(50,), max_iter=10000; total time=   3.1s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   5.0s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   3.9s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   5.2s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   4.7s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   3.9s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   4.6s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   5.7s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   4.8s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   4.7s
# [CV] END ..........hidden_layer_sizes=(200,), max_iter=10000; total time=   3.8s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   7.5s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   6.7s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   5.3s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   8.6s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   9.9s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   7.4s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   6.1s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   5.0s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   9.1s
# [CV] END ..........hidden_layer_sizes=(500,), max_iter=10000; total time=   5.4s
# Best parameters found:  {'hidden_layer_sizes': (50,), 'max_iter': 10000}

# %% [markdown]
# A very simple neural network with the hidden layer size of 50

# %%
clf = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=10000, tol=1e-6)
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 112
# TN = 192
# FP = 11
# FN = 15
# Precision = 0.9105691056910569
# Recall = 0.8818897637795275
# Accuracy = 0.9212121212121213
# TSS = 0.8277025716613009
# HSS = 0.832611494791057

# %% [markdown]
# Random forest

# %%
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 198
# FP = 5
# FN = 9
# Precision = 0.959349593495935
# Recall = 0.9291338582677166
# Accuracy = 0.9575757575757575
# TSS = 0.9045033163957954
# HSS = 0.9098677279644153

# %% [markdown]
# ## Test 2. Separation into chunks of data.

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_moments.npy')
labels_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_labels.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_timep.npy')
print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 997
# Among them unstable (positive) samples: 392

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=10000)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
# Out:
# The size of the chunk: 2
# Number of positive - negative samples in train: 197.0 --- 302.0
# Number of positive - negative samples in test: 195.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 170
# TN = 287
# FP = 16
# FN = 25
# Precision = 0.9139784946236559
# Recall = 0.8717948717948718
# Accuracy = 0.9176706827309237
# TSS = 0.818989591266819
# HSS = 0.8257820099319101
# The size of the chunk: 4
# Number of positive - negative samples in train: 201.0 --- 299.0
# Number of positive - negative samples in test: 191.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 164
# TN = 284
# FP = 22
# FN = 27
# Precision = 0.8817204301075269
# Recall = 0.8586387434554974
# Accuracy = 0.9014084507042254
# TSS = 0.7867433186188961
# HSS = 0.7906324956799092
# The size of the chunk: 6
# Number of positive - negative samples in train: 186.0 --- 313.0
# Number of positive - negative samples in test: 206.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 164
# TN = 283
# FP = 9
# FN = 42
# Precision = 0.9479768786127167
# Recall = 0.7961165048543689
# Accuracy = 0.8975903614457831
# TSS = 0.7652945870461497
# HSS = 0.7837842439514413
# The size of the chunk: 8
# Number of positive - negative samples in train: 207.0 --- 294.0
# Number of positive - negative samples in test: 185.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 161
# TN = 263
# FP = 48
# FN = 24
# Precision = 0.7703349282296651
# Recall = 0.8702702702702703
# Accuracy = 0.8548387096774194
# TSS = 0.7159294342574085
# HSS = 0.6975968296441818
# The size of the chunk: 10
# Number of positive - negative samples in train: 180.0 --- 320.0
# Number of positive - negative samples in test: 212.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 163
# TN = 271
# FP = 14
# FN = 49
# Precision = 0.9209039548022598
# Recall = 0.7688679245283019
# Accuracy = 0.8732394366197183
# TSS = 0.719745117510758
# HSS = 0.7352918797818827
# The size of the chunk: 12
# Number of positive - negative samples in train: 190.0 --- 314.0
# Number of positive - negative samples in test: 202.0 --- 291.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 268
# FP = 23
# FN = 48
# Precision = 0.8700564971751412
# Recall = 0.7623762376237624
# Accuracy = 0.8559837728194726
# TSS = 0.6833384369364772
# HSS = 0.6965206911799131
# The size of the chunk: 14
# Number of positive - negative samples in train: 183.0 --- 321.0
# Number of positive - negative samples in test: 209.0 --- 284.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 159
# TN = 254
# FP = 30
# FN = 50
# Precision = 0.8412698412698413
# Recall = 0.7607655502392344
# Accuracy = 0.8377281947261663
# TSS = 0.655131747422333
# HSS = 0.6635156809882947
# The size of the chunk: 16
# Number of positive - negative samples in train: 201.0 --- 300.0
# Number of positive - negative samples in test: 191.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 151
# TN = 262
# FP = 43
# FN = 40
# Precision = 0.7783505154639175
# Recall = 0.7905759162303665
# Accuracy = 0.8326612903225806
# TSS = 0.6495923096729894
# HSS = 0.6476910964296717
# The size of the chunk: 18
# Number of positive - negative samples in train: 170.0 --- 334.0
# Number of positive - negative samples in test: 222.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 140
# TN = 249
# FP = 22
# FN = 82
# Precision = 0.8641975308641975
# Recall = 0.6306306306306306
# Accuracy = 0.7890466531440162
# TSS = 0.5494498188225125
# HSS = 0.5632113405574866
# The size of the chunk: 20
# Number of positive - negative samples in train: 198.0 --- 302.0
# Number of positive - negative samples in test: 194.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 148
# TN = 257
# FP = 46
# FN = 46
# Precision = 0.7628865979381443
# Recall = 0.7628865979381443
# Accuracy = 0.8148893360160966
# TSS = 0.6110714164199924
# HSS = 0.6110714164199925
# The size of the chunk: 22
# Number of positive - negative samples in train: 212.0 --- 294.0
# Number of positive - negative samples in test: 180.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 122
# TN = 258
# FP = 53
# FN = 58
# Precision = 0.6971428571428572
# Recall = 0.6777777777777778
# Accuracy = 0.7739307535641547
# TSS = 0.5073597713469097
# HSS = 0.5103454471946454
# The size of the chunk: 24
# Number of positive - negative samples in train: 180.0 --- 324.0
# Number of positive - negative samples in test: 212.0 --- 281.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 120
# TN = 235
# FP = 46
# FN = 92
# Precision = 0.7228915662650602
# Recall = 0.5660377358490566
# Accuracy = 0.7200811359026369
# TSS = 0.4023366682333982
# HSS = 0.41334827972751575
# The size of the chunk: 26
# Number of positive - negative samples in train: 204.0 --- 299.0
# Number of positive - negative samples in test: 188.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 120
# TN = 266
# FP = 40
# FN = 68
# Precision = 0.75
# Recall = 0.6382978723404256
# Accuracy = 0.7813765182186235
# TSS = 0.5075789180920596
# HSS = 0.5225857255351135
# The size of the chunk: 28
# Number of positive - negative samples in train: 196.0 --- 308.0
# Number of positive - negative samples in test: 196.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 172
# TN = 248
# FP = 49
# FN = 24
# Precision = 0.7782805429864253
# Recall = 0.8775510204081632
# Accuracy = 0.8519269776876268
# TSS = 0.7125678554249982
# HSS = 0.6974417607546091
# The size of the chunk: 30
# Number of positive - negative samples in train: 211.0 --- 299.0
# Number of positive - negative samples in test: 181.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 91
# TN = 262
# FP = 44
# FN = 90
# Precision = 0.674074074074074
# Recall = 0.5027624309392266
# Accuracy = 0.7248459958932238
# TSS = 0.35897158126602396
# HSS = 0.3786254308621051
# The size of the chunk: 32
# Number of positive - negative samples in train: 211.0 --- 301.0
# Number of positive - negative samples in test: 181.0 --- 304.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 275
# FP = 29
# FN = 43
# Precision = 0.8263473053892215
# Recall = 0.7624309392265194
# Accuracy = 0.8515463917525773
# TSS = 0.6670362023844141
# HSS = 0.677639717150084
# The size of the chunk: 34
# Number of positive - negative samples in train: 168.0 --- 342.0
# Number of positive - negative samples in test: 224.0 --- 263.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 196
# TN = 223
# FP = 40
# FN = 28
# Precision = 0.8305084745762712
# Recall = 0.875
# Accuracy = 0.8603696098562629
# TSS = 0.7229087452471483
# HSS = 0.7200486930646197
# The size of the chunk: 36
# Number of positive - negative samples in train: 193.0 --- 311.0
# Number of positive - negative samples in test: 199.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 131
# TN = 261
# FP = 33
# FN = 68
# Precision = 0.7987804878048781
# Recall = 0.6582914572864321
# Accuracy = 0.795131845841785
# TSS = 0.5460465593272484
# HSS = 0.5620167653293693
# The size of the chunk: 38
# Number of positive - negative samples in train: 197.0 --- 306.0
# Number of positive - negative samples in test: 195.0 --- 299.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 120
# TN = 249
# FP = 50
# FN = 75
# Precision = 0.7058823529411765
# Recall = 0.6153846153846154
# Accuracy = 0.7469635627530364
# TSS = 0.4481605351170569
# HSS = 0.4583808437856328
# The size of the chunk: 40
# Number of positive - negative samples in train: 209.0 --- 308.0
# Number of positive - negative samples in test: 183.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 236
# FP = 61
# FN = 45
# Precision = 0.6934673366834171
# Recall = 0.7540983606557377
# Accuracy = 0.7791666666666667
# TSS = 0.5487111552685322
# HSS = 0.5396558275880788
# The size of the chunk: 42
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 151
# TN = 228
# FP = 40
# FN = 74
# Precision = 0.7905759162303665
# Recall = 0.6711111111111111
# Accuracy = 0.768762677484787
# TSS = 0.5218573797678275
# HSS = 0.5282613439876446
# The size of the chunk: 44
# Number of positive - negative samples in train: 211.0 --- 302.0
# Number of positive - negative samples in test: 181.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 130
# TN = 245
# FP = 58
# FN = 51
# Precision = 0.6914893617021277
# Recall = 0.7182320441988951
# Accuracy = 0.7747933884297521
# TSS = 0.5268129022847037
# HSS = 0.5227428984982811
# The size of the chunk: 46
# Number of positive - negative samples in train: 206.0 --- 300.0
# Number of positive - negative samples in test: 186.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 86
# TN = 234
# FP = 71
# FN = 100
# Precision = 0.5477707006369427
# Recall = 0.46236559139784944
# Accuracy = 0.6517311608961304
# TSS = 0.2295787061519478
# HSS = 0.23678062703960584
# The size of the chunk: 48
# Number of positive - negative samples in train: 183.0 --- 334.0
# Number of positive - negative samples in test: 209.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 149
# TN = 236
# FP = 35
# FN = 60
# Precision = 0.8097826086956522
# Recall = 0.7129186602870813
# Accuracy = 0.8020833333333334
# TSS = 0.5837673687741661
# HSS = 0.5918659601890305
# The size of the chunk: 50
# Number of positive - negative samples in train: 189.0 --- 311.0
# Number of positive - negative samples in test: 203.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 162
# TN = 205
# FP = 89
# FN = 41
# Precision = 0.6454183266932271
# Recall = 0.7980295566502463
# Accuracy = 0.738430583501006
# TSS = 0.4953084682148722
# HSS = 0.47782303688617334
# The size of the chunk: 52
# Number of positive - negative samples in train: 224.0 --- 296.0
# Number of positive - negative samples in test: 168.0 --- 309.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 132
# TN = 242
# FP = 67
# FN = 36
# Precision = 0.6633165829145728
# Recall = 0.7857142857142857
# Accuracy = 0.7840670859538784
# TSS = 0.5688858067498844
# HSS = 0.5459032302786635
# The size of the chunk: 54
# Number of positive - negative samples in train: 202.0 --- 309.0
# Number of positive - negative samples in test: 190.0 --- 296.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 79
# TN = 233
# FP = 63
# FN = 111
# Precision = 0.5563380281690141
# Recall = 0.41578947368421054
# Accuracy = 0.6419753086419753
# TSS = 0.2029516358463727
# HSS = 0.2125670441001192
# The size of the chunk: 56
# Number of positive - negative samples in train: 169.0 --- 335.0
# Number of positive - negative samples in test: 223.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 130
# TN = 202
# FP = 68
# FN = 93
# Precision = 0.6565656565656566
# Recall = 0.5829596412556054
# Accuracy = 0.6734279918864098
# TSS = 0.33110778940375357
# HSS = 0.3343704138538304
# The size of the chunk: 58
# Number of positive - negative samples in train: 174.0 --- 348.0
# Number of positive - negative samples in test: 218.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 127
# TN = 246
# FP = 11
# FN = 91
# Precision = 0.9202898550724637
# Recall = 0.5825688073394495
# Accuracy = 0.7852631578947369
# TSS = 0.5397672509192161
# HSS = 0.555227114162964
# The size of the chunk: 60
# Number of positive - negative samples in train: 220.0 --- 297.0
# Number of positive - negative samples in test: 172.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 236
# FP = 72
# FN = 27
# Precision = 0.6682027649769585
# Recall = 0.8430232558139535
# Accuracy = 0.79375
# TSS = 0.6092570220477198
# HSS = 0.5759868655864088
# The size of the chunk: 62
# Number of positive - negative samples in train: 249.0 --- 252.0
# Number of positive - negative samples in test: 143.0 --- 353.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 111
# TN = 300
# FP = 53
# FN = 32
# Precision = 0.676829268292683
# Recall = 0.7762237762237763
# Accuracy = 0.8286290322580645
# TSS = 0.6260821331642862
# HSS = 0.5998785209930909
# The size of the chunk: 64
# Number of positive - negative samples in train: 221.0 --- 291.0
# Number of positive - negative samples in test: 171.0 --- 314.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 96
# TN = 293
# FP = 21
# FN = 75
# Precision = 0.8205128205128205
# Recall = 0.5614035087719298
# Accuracy = 0.8020618556701031
# TSS = 0.49452452788021006
# HSS = 0.532839684546385
# The size of the chunk: 66
# Number of positive - negative samples in train: 184.0 --- 344.0
# Number of positive - negative samples in test: 208.0 --- 261.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 164
# TN = 136
# FP = 125
# FN = 44
# Precision = 0.5674740484429066
# Recall = 0.7884615384615384
# Accuracy = 0.6396588486140725
# TSS = 0.30953433539640435
# HSS = 0.29776112129991406
# The size of the chunk: 68
# Number of positive - negative samples in train: 153.0 --- 368.0
# Number of positive - negative samples in test: 239.0 --- 237.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 177
# TN = 215
# FP = 22
# FN = 62
# Precision = 0.8894472361809045
# Recall = 0.7405857740585774
# Accuracy = 0.8235294117647058
# TSS = 0.6477587698391681
# HSS = 0.6473016601097331
# The size of the chunk: 70
# Number of positive - negative samples in train: 160.0 --- 347.0
# Number of positive - negative samples in test: 232.0 --- 258.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 91
# TN = 213
# FP = 45
# FN = 141
# Precision = 0.6691176470588235
# Recall = 0.3922413793103448
# Accuracy = 0.6204081632653061
# TSS = 0.217822774659182
# HSS = 0.22246109746109746
# The size of the chunk: 72
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 84
# TN = 220
# FP = 48
# FN = 141
# Precision = 0.6363636363636364
# Recall = 0.37333333333333335
# Accuracy = 0.6166328600405679
# TSS = 0.19422885572139306
# HSS = 0.2008902153497826
# The size of the chunk: 74
# Number of positive - negative samples in train: 183.0 --- 335.0
# Number of positive - negative samples in test: 209.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 125
# TN = 153
# FP = 117
# FN = 84
# Precision = 0.5165289256198347
# Recall = 0.5980861244019139
# Accuracy = 0.5803757828810021
# TSS = 0.16475279106858054
# HSS = 0.1618657125695333
# The size of the chunk: 76
# Number of positive - negative samples in train: 184.0 --- 348.0
# Number of positive - negative samples in test: 208.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 125
# TN = 217
# FP = 40
# FN = 83
# Precision = 0.7575757575757576
# Recall = 0.6009615384615384
# Accuracy = 0.7354838709677419
# TSS = 0.44531951511523493
# HSS = 0.45427221983683985
# The size of the chunk: 78
# Number of positive - negative samples in train: 209.0 --- 320.0
# Number of positive - negative samples in test: 183.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 107
# TN = 199
# FP = 86
# FN = 76
# Precision = 0.5544041450777202
# Recall = 0.5846994535519126
# Accuracy = 0.6538461538461539
# TSS = 0.2829450675870003
# HSS = 0.28020506978068926
# The size of the chunk: 80
# Number of positive - negative samples in train: 218.0 --- 299.0
# Number of positive - negative samples in test: 174.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 125
# TN = 196
# FP = 110
# FN = 49
# Precision = 0.5319148936170213
# Recall = 0.7183908045977011
# Accuracy = 0.66875
# TSS = 0.35891368041469457
# HSS = 0.33368255631220534
# The size of the chunk: 82
# Number of positive - negative samples in train: 224.0 --- 281.0
# Number of positive - negative samples in test: 168.0 --- 324.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 114
# TN = 242
# FP = 82
# FN = 54
# Precision = 0.5816326530612245
# Recall = 0.6785714285714286
# Accuracy = 0.7235772357723578
# TSS = 0.42548500881834217
# HSS = 0.4090716405256465
# The size of the chunk: 84
# Number of positive - negative samples in train: 221.0 --- 283.0
# Number of positive - negative samples in test: 171.0 --- 322.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 100
# TN = 221
# FP = 101
# FN = 71
# Precision = 0.4975124378109453
# Recall = 0.5847953216374269
# Accuracy = 0.6511156186612576
# TSS = 0.27113072536413496
# HSS = 0.26041830202173494
# The size of the chunk: 86
# Number of positive - negative samples in train: 219.0 --- 297.0
# Number of positive - negative samples in test: 173.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 88
# TN = 189
# FP = 119
# FN = 85
# Precision = 0.4251207729468599
# Recall = 0.5086705202312138
# Accuracy = 0.5758835758835759
# TSS = 0.12230688386757749
# HSS = 0.11725651774950971
# The size of the chunk: 88
# Number of positive - negative samples in train: 218.0 --- 310.0
# Number of positive - negative samples in test: 174.0 --- 295.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 89
# TN = 216
# FP = 79
# FN = 85
# Precision = 0.5297619047619048
# Recall = 0.5114942528735632
# Accuracy = 0.650319829424307
# TSS = 0.24369764270407168
# HSS = 0.2454333195989562
# The size of the chunk: 90
# Number of positive - negative samples in train: 202.0 --- 338.0
# Number of positive - negative samples in test: 190.0 --- 267.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 115
# TN = 190
# FP = 77
# FN = 75
# Precision = 0.5989583333333334
# Recall = 0.6052631578947368
# Accuracy = 0.6673960612691466
# TSS = 0.3168736447861226
# HSS = 0.3163934103568406
# The size of the chunk: 92
# Number of positive - negative samples in train: 208.0 --- 329.0
# Number of positive - negative samples in test: 184.0 --- 276.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 132
# TN = 159
# FP = 117
# FN = 52
# Precision = 0.5301204819277109
# Recall = 0.717391304347826
# Accuracy = 0.6326086956521739
# TSS = 0.2934782608695652
# HSS = 0.2771599657827203
# The size of the chunk: 94
# Number of positive - negative samples in train: 214.0 --- 313.0
# Number of positive - negative samples in test: 178.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 146
# TN = 148
# FP = 144
# FN = 32
# Precision = 0.503448275862069
# Recall = 0.8202247191011236
# Accuracy = 0.625531914893617
# TSS = 0.3270740341696168
# HSS = 0.29129540781357094
# The size of the chunk: 96
# Number of positive - negative samples in train: 229.0 --- 288.0
# Number of positive - negative samples in test: 163.0 --- 317.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 135
# TN = 204
# FP = 113
# FN = 28
# Precision = 0.5443548387096774
# Recall = 0.8282208588957055
# Accuracy = 0.70625
# TSS = 0.4717539819240967
# HSS = 0.41871650405386834
# The size of the chunk: 98
# Number of positive - negative samples in train: 234.0 --- 273.0
# Number of positive - negative samples in test: 158.0 --- 332.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 113
# TN = 266
# FP = 66
# FN = 45
# Precision = 0.6312849162011173
# Recall = 0.7151898734177216
# Accuracy = 0.773469387755102
# TSS = 0.51639469269483
# HSS = 0.4990144244054308
# The size of the chunk: 100
# Number of positive - negative samples in train: 242.0 --- 258.0
# Number of positive - negative samples in test: 150.0 --- 347.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 144
# TN = 120
# FP = 227
# FN = 6
# Precision = 0.3881401617250674
# Recall = 0.96
# Accuracy = 0.5311871227364185
# TSS = 0.3058213256484149
# HSS = 0.21563700156464843

# %%
im, ax = plt.subplots(1, 1, figsize=(6,5), dpi=120)
ax.plot(chunksizes, output_scores)
ax.set(xlim=[0.0,105.0], ylim=[0.5,1.0], xlabel='Size of the chunk, # samples', ylabel='Accuracy', \
       title='Classifier: Neural Network (1 hidden layer, 50 nodes)')
plt.tight_layout()
plt.show()

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = SVC(kernel='rbf', class_weight='balanced')
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
# Out:
# The size of the chunk: 2
# Number of positive - negative samples in train: 197.0 --- 302.0
# Number of positive - negative samples in test: 195.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 169
# TN = 257
# FP = 46
# FN = 26
# Precision = 0.786046511627907
# Recall = 0.8666666666666667
# Accuracy = 0.8554216867469879
# TSS = 0.7148514851485148
# HSS = 0.7020194465220643
# The size of the chunk: 4
# Number of positive - negative samples in train: 201.0 --- 299.0
# Number of positive - negative samples in test: 191.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 167
# TN = 259
# FP = 47
# FN = 24
# Precision = 0.780373831775701
# Recall = 0.8743455497382199
# Accuracy = 0.8571428571428571
# TSS = 0.7207507784963898
# HSS = 0.7048026970728728
# The size of the chunk: 6
# Number of positive - negative samples in train: 186.0 --- 313.0
# Number of positive - negative samples in test: 206.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 173
# TN = 254
# FP = 38
# FN = 33
# Precision = 0.8199052132701422
# Recall = 0.8398058252427184
# Accuracy = 0.857429718875502
# TSS = 0.7096688389413486
# HSS = 0.7071413189325294
# The size of the chunk: 8
# Number of positive - negative samples in train: 207.0 --- 294.0
# Number of positive - negative samples in test: 185.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 156
# TN = 252
# FP = 59
# FN = 29
# Precision = 0.7255813953488373
# Recall = 0.8432432432432433
# Accuracy = 0.8225806451612904
# TSS = 0.6535326323107674
# HSS = 0.6327471602860749
# The size of the chunk: 10
# Number of positive - negative samples in train: 180.0 --- 320.0
# Number of positive - negative samples in test: 212.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 171
# TN = 253
# FP = 32
# FN = 41
# Precision = 0.8423645320197044
# Recall = 0.8066037735849056
# Accuracy = 0.8531187122736419
# TSS = 0.6943230718305197
# HSS = 0.6981187023123071
# The size of the chunk: 12
# Number of positive - negative samples in train: 190.0 --- 314.0
# Number of positive - negative samples in test: 202.0 --- 291.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 159
# TN = 254
# FP = 37
# FN = 43
# Precision = 0.8112244897959183
# Recall = 0.7871287128712872
# Accuracy = 0.8377281947261663
# TSS = 0.6599809465482631
# HSS = 0.6629923951123643
# The size of the chunk: 14
# Number of positive - negative samples in train: 183.0 --- 321.0
# Number of positive - negative samples in test: 209.0 --- 284.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 170
# TN = 235
# FP = 49
# FN = 39
# Precision = 0.776255707762557
# Recall = 0.8133971291866029
# Accuracy = 0.821501014198783
# TSS = 0.6408619179189973
# HSS = 0.6368384925750448
# The size of the chunk: 16
# Number of positive - negative samples in train: 201.0 --- 300.0
# Number of positive - negative samples in test: 191.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 234
# FP = 71
# FN = 37
# Precision = 0.6844444444444444
# Recall = 0.806282722513089
# Accuracy = 0.782258064516129
# TSS = 0.5734958372671873
# HSS = 0.5550313159337464
# The size of the chunk: 18
# Number of positive - negative samples in train: 170.0 --- 334.0
# Number of positive - negative samples in test: 222.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 147
# TN = 243
# FP = 28
# FN = 75
# Precision = 0.84
# Recall = 0.6621621621621622
# Accuracy = 0.7910750507099391
# TSS = 0.55884112895183
# HSS = 0.5697460621414833
# The size of the chunk: 20
# Number of positive - negative samples in train: 198.0 --- 302.0
# Number of positive - negative samples in test: 194.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 226
# FP = 77
# FN = 49
# Precision = 0.6531531531531531
# Recall = 0.7474226804123711
# Accuracy = 0.7464788732394366
# TSS = 0.493297267871117
# HSS = 0.48081514890230154
# The size of the chunk: 22
# Number of positive - negative samples in train: 212.0 --- 294.0
# Number of positive - negative samples in test: 180.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 135
# TN = 232
# FP = 79
# FN = 45
# Precision = 0.6308411214953271
# Recall = 0.75
# Accuracy = 0.7474541751527495
# TSS = 0.4959807073954984
# HSS = 0.47700448399677015
# The size of the chunk: 24
# Number of positive - negative samples in train: 180.0 --- 324.0
# Number of positive - negative samples in test: 212.0 --- 281.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 119
# TN = 215
# FP = 66
# FN = 93
# Precision = 0.6432432432432432
# Recall = 0.5613207547169812
# Accuracy = 0.6774847870182555
# TSS = 0.3264453098771235
# HSS = 0.3316308694502946
# The size of the chunk: 26
# Number of positive - negative samples in train: 204.0 --- 299.0
# Number of positive - negative samples in test: 188.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 129
# TN = 238
# FP = 68
# FN = 59
# Precision = 0.6548223350253807
# Recall = 0.6861702127659575
# Accuracy = 0.742914979757085
# TSS = 0.46394799054373526
# HSS = 0.45970478306550233
# The size of the chunk: 28
# Number of positive - negative samples in train: 196.0 --- 308.0
# Number of positive - negative samples in test: 196.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 176
# TN = 221
# FP = 76
# FN = 20
# Precision = 0.6984126984126984
# Recall = 0.8979591836734694
# Accuracy = 0.8052738336713996
# TSS = 0.6420669277812134
# HSS = 0.6123197903014417
# The size of the chunk: 30
# Number of positive - negative samples in train: 211.0 --- 299.0
# Number of positive - negative samples in test: 181.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 94
# TN = 252
# FP = 54
# FN = 87
# Precision = 0.6351351351351351
# Recall = 0.5193370165745856
# Accuracy = 0.7104722792607803
# TSS = 0.3428664283392915
# HSS = 0.3561281611297083
# The size of the chunk: 32
# Number of positive - negative samples in train: 211.0 --- 301.0
# Number of positive - negative samples in test: 181.0 --- 304.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 230
# FP = 74
# FN = 27
# Precision = 0.6754385964912281
# Recall = 0.850828729281768
# Accuracy = 0.7917525773195876
# TSS = 0.607407676650189
# HSS = 0.5770920926538259
# The size of the chunk: 34
# Number of positive - negative samples in train: 168.0 --- 342.0
# Number of positive - negative samples in test: 224.0 --- 263.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 199
# TN = 201
# FP = 62
# FN = 25
# Precision = 0.7624521072796935
# Recall = 0.8883928571428571
# Accuracy = 0.8213552361396304
# TSS = 0.6526514122759369
# HSS = 0.6447550454023325
# The size of the chunk: 36
# Number of positive - negative samples in train: 193.0 --- 311.0
# Number of positive - negative samples in test: 199.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 120
# TN = 240
# FP = 54
# FN = 79
# Precision = 0.6896551724137931
# Recall = 0.6030150753768844
# Accuracy = 0.7302231237322515
# TSS = 0.4193416059891293
# HSS = 0.42802934480141663
# The size of the chunk: 38
# Number of positive - negative samples in train: 197.0 --- 306.0
# Number of positive - negative samples in test: 195.0 --- 299.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 124
# TN = 239
# FP = 60
# FN = 71
# Precision = 0.6739130434782609
# Recall = 0.6358974358974359
# Accuracy = 0.7348178137651822
# TSS = 0.43522853957636565
# HSS = 0.4395406439990993
# The size of the chunk: 40
# Number of positive - negative samples in train: 209.0 --- 308.0
# Number of positive - negative samples in test: 183.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 141
# TN = 185
# FP = 112
# FN = 42
# Precision = 0.5573122529644269
# Recall = 0.7704918032786885
# Accuracy = 0.6791666666666667
# TSS = 0.3933874261743114
# HSS = 0.3664832621998252
# The size of the chunk: 42
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 171
# TN = 202
# FP = 66
# FN = 54
# Precision = 0.7215189873417721
# Recall = 0.76
# Accuracy = 0.7565922920892495
# TSS = 0.5137313432835822
# HSS = 0.511542653324086
# The size of the chunk: 44
# Number of positive - negative samples in train: 211.0 --- 302.0
# Number of positive - negative samples in test: 181.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 116
# TN = 215
# FP = 88
# FN = 65
# Precision = 0.5686274509803921
# Recall = 0.6408839779005525
# Accuracy = 0.6838842975206612
# TSS = 0.35045493499626207
# HSS = 0.341713188493404
# The size of the chunk: 46
# Number of positive - negative samples in train: 206.0 --- 300.0
# Number of positive - negative samples in test: 186.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 82
# TN = 239
# FP = 66
# FN = 104
# Precision = 0.5540540540540541
# Recall = 0.44086021505376344
# Accuracy = 0.6537678207739308
# TSS = 0.22446677243081262
# HSS = 0.23378435440342213
# The size of the chunk: 48
# Number of positive - negative samples in train: 183.0 --- 334.0
# Number of positive - negative samples in test: 209.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 146
# TN = 218
# FP = 53
# FN = 63
# Precision = 0.7336683417085427
# Recall = 0.6985645933014354
# Accuracy = 0.7583333333333333
# TSS = 0.5029926375818782
# HSS = 0.5057607981679064
# The size of the chunk: 50
# Number of positive - negative samples in train: 189.0 --- 311.0
# Number of positive - negative samples in test: 203.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 214
# FP = 80
# FN = 43
# Precision = 0.6666666666666666
# Recall = 0.7881773399014779
# Accuracy = 0.7525150905432596
# TSS = 0.5160684963640629
# HSS = 0.5019106827125991
# The size of the chunk: 52
# Number of positive - negative samples in train: 224.0 --- 296.0
# Number of positive - negative samples in test: 168.0 --- 309.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 156
# FP = 153
# FN = 23
# Precision = 0.4865771812080537
# Recall = 0.8630952380952381
# Accuracy = 0.6310272536687631
# TSS = 0.36794960702727697
# HSS = 0.31273638194410336
# The size of the chunk: 54
# Number of positive - negative samples in train: 202.0 --- 309.0
# Number of positive - negative samples in test: 190.0 --- 296.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 89
# TN = 257
# FP = 39
# FN = 101
# Precision = 0.6953125
# Recall = 0.46842105263157896
# Accuracy = 0.7119341563786008
# TSS = 0.3366642958748222
# HSS = 0.3575556143067568
# The size of the chunk: 56
# Number of positive - negative samples in train: 169.0 --- 335.0
# Number of positive - negative samples in test: 223.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 113
# TN = 234
# FP = 36
# FN = 110
# Precision = 0.7583892617449665
# Recall = 0.5067264573991032
# Accuracy = 0.7038539553752535
# TSS = 0.37339312406576985
# HSS = 0.3844982983017222
# The size of the chunk: 58
# Number of positive - negative samples in train: 174.0 --- 348.0
# Number of positive - negative samples in test: 218.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 116
# TN = 206
# FP = 51
# FN = 102
# Precision = 0.6946107784431138
# Recall = 0.5321100917431193
# Accuracy = 0.6778947368421052
# TSS = 0.33366651197658237
# HSS = 0.3396963557235402
# The size of the chunk: 60
# Number of positive - negative samples in train: 220.0 --- 297.0
# Number of positive - negative samples in test: 172.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 143
# TN = 247
# FP = 61
# FN = 29
# Precision = 0.7009803921568627
# Recall = 0.8313953488372093
# Accuracy = 0.8125
# TSS = 0.6333434007852613
# HSS = 0.608355091383812
# The size of the chunk: 62
# Number of positive - negative samples in train: 249.0 --- 252.0
# Number of positive - negative samples in test: 143.0 --- 353.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 109
# TN = 231
# FP = 122
# FN = 34
# Precision = 0.47186147186147187
# Recall = 0.7622377622377622
# Accuracy = 0.6854838709677419
# TSS = 0.4166286970819548
# HSS = 0.3521659773271488
# The size of the chunk: 64
# Number of positive - negative samples in train: 221.0 --- 291.0
# Number of positive - negative samples in test: 171.0 --- 314.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 134
# TN = 213
# FP = 101
# FN = 37
# Precision = 0.5702127659574469
# Recall = 0.783625730994152
# Accuracy = 0.7154639175257732
# TSS = 0.461969680038738
# HSS = 0.42569074995709627
# The size of the chunk: 66
# Number of positive - negative samples in train: 184.0 --- 344.0
# Number of positive - negative samples in test: 208.0 --- 261.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 198
# TN = 114
# FP = 147
# FN = 10
# Precision = 0.5739130434782609
# Recall = 0.9519230769230769
# Accuracy = 0.6652452025586354
# TSS = 0.3887046861184792
# HSS = 0.3643395460863109
# The size of the chunk: 68
# Number of positive - negative samples in train: 153.0 --- 368.0
# Number of positive - negative samples in test: 239.0 --- 237.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 188
# TN = 129
# FP = 108
# FN = 51
# Precision = 0.6351351351351351
# Recall = 0.7866108786610879
# Accuracy = 0.6659663865546218
# TSS = 0.33091467612944236
# HSS = 0.331248011875729
# The size of the chunk: 70
# Number of positive - negative samples in train: 160.0 --- 347.0
# Number of positive - negative samples in test: 232.0 --- 258.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 76
# TN = 191
# FP = 67
# FN = 156
# Precision = 0.5314685314685315
# Recall = 0.3275862068965517
# Accuracy = 0.5448979591836735
# TSS = 0.06789628441593154
# HSS = 0.06923456958380893
# The size of the chunk: 72
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 74
# TN = 179
# FP = 89
# FN = 151
# Precision = 0.4539877300613497
# Recall = 0.3288888888888889
# Accuracy = 0.513184584178499
# TSS = -0.003200663349917088
# HSS = -0.003273017111265623
# The size of the chunk: 74
# Number of positive - negative samples in train: 183.0 --- 335.0
# Number of positive - negative samples in test: 209.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 82
# TN = 170
# FP = 100
# FN = 127
# Precision = 0.45054945054945056
# Recall = 0.3923444976076555
# Accuracy = 0.5260960334029228
# TSS = 0.021974127237285146
# HSS = 0.022299551311447403
# The size of the chunk: 76
# Number of positive - negative samples in train: 184.0 --- 348.0
# Number of positive - negative samples in test: 208.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 152
# FP = 105
# FN = 90
# Precision = 0.5291479820627802
# Recall = 0.5673076923076923
# Accuracy = 0.5806451612903226
# TSS = 0.1587473810236456
# HSS = 0.15766347413304596
# The size of the chunk: 78
# Number of positive - negative samples in train: 209.0 --- 320.0
# Number of positive - negative samples in test: 183.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 155
# TN = 142
# FP = 143
# FN = 28
# Precision = 0.5201342281879194
# Recall = 0.8469945355191257
# Accuracy = 0.6346153846153846
# TSS = 0.34524014955421345
# HSS = 0.31034126163391934
# The size of the chunk: 80
# Number of positive - negative samples in train: 218.0 --- 299.0
# Number of positive - negative samples in test: 174.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 145
# TN = 188
# FP = 118
# FN = 29
# Precision = 0.5513307984790875
# Recall = 0.8333333333333334
# Accuracy = 0.69375
# TSS = 0.4477124183006536
# HSS = 0.40322744341824823
# The size of the chunk: 82
# Number of positive - negative samples in train: 224.0 --- 281.0
# Number of positive - negative samples in test: 168.0 --- 324.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 131
# TN = 222
# FP = 102
# FN = 37
# Precision = 0.5622317596566524
# Recall = 0.7797619047619048
# Accuracy = 0.717479674796748
# TSS = 0.46494708994708994
# HSS = 0.42533024100030253
# The size of the chunk: 84
# Number of positive - negative samples in train: 221.0 --- 283.0
# Number of positive - negative samples in test: 171.0 --- 322.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 86
# TN = 243
# FP = 79
# FN = 85
# Precision = 0.5212121212121212
# Recall = 0.5029239766081871
# Accuracy = 0.6673427991886409
# TSS = 0.25758236170135484
# HSS = 0.25971909392224724
# The size of the chunk: 86
# Number of positive - negative samples in train: 219.0 --- 297.0
# Number of positive - negative samples in test: 173.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 51
# TN = 230
# FP = 78
# FN = 122
# Precision = 0.3953488372093023
# Recall = 0.2947976878612717
# Accuracy = 0.5841995841995842
# TSS = 0.041550934614518475
# HSS = 0.04400365703382756
# The size of the chunk: 88
# Number of positive - negative samples in train: 218.0 --- 310.0
# Number of positive - negative samples in test: 174.0 --- 295.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 107
# TN = 205
# FP = 90
# FN = 67
# Precision = 0.5431472081218274
# Recall = 0.6149425287356322
# Accuracy = 0.6652452025586354
# TSS = 0.30985778297292027
# HSS = 0.3016795804368237
# The size of the chunk: 90
# Number of positive - negative samples in train: 202.0 --- 338.0
# Number of positive - negative samples in test: 190.0 --- 267.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 131
# TN = 186
# FP = 81
# FN = 59
# Precision = 0.6179245283018868
# Recall = 0.6894736842105263
# Accuracy = 0.6936542669584245
# TSS = 0.3861028976936724
# HSS = 0.37976229714795356
# The size of the chunk: 92
# Number of positive - negative samples in train: 208.0 --- 329.0
# Number of positive - negative samples in test: 184.0 --- 276.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 150
# TN = 186
# FP = 90
# FN = 34
# Precision = 0.625
# Recall = 0.8152173913043478
# Accuracy = 0.7304347826086957
# TSS = 0.48913043478260865
# HSS = 0.46551724137931033
# The size of the chunk: 94
# Number of positive - negative samples in train: 214.0 --- 313.0
# Number of positive - negative samples in test: 178.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 152
# TN = 164
# FP = 128
# FN = 26
# Precision = 0.5428571428571428
# Recall = 0.8539325842696629
# Accuracy = 0.6723404255319149
# TSS = 0.4155764198861013
# HSS = 0.3737670877314414
# The size of the chunk: 96
# Number of positive - negative samples in train: 229.0 --- 288.0
# Number of positive - negative samples in test: 163.0 --- 317.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 173
# FP = 144
# FN = 9
# Precision = 0.5167785234899329
# Recall = 0.9447852760736196
# Accuracy = 0.68125
# TSS = 0.49052660099475526
# HSS = 0.40837173331614735
# The size of the chunk: 98
# Number of positive - negative samples in train: 234.0 --- 273.0
# Number of positive - negative samples in test: 158.0 --- 332.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 209
# FP = 123
# FN = 40
# Precision = 0.4896265560165975
# Recall = 0.7468354430379747
# Accuracy = 0.6673469387755102
# TSS = 0.3763535153271313
# HSS = 0.3308142165323324
# The size of the chunk: 100
# Number of positive - negative samples in train: 242.0 --- 258.0
# Number of positive - negative samples in test: 150.0 --- 347.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 144
# TN = 117
# FP = 230
# FN = 6
# Precision = 0.3850267379679144
# Recall = 0.96
# Accuracy = 0.5251509054325956
# TSS = 0.2971757925072046
# HSS = 0.2087055077313328

# %%
im, ax = plt.subplots(1, 1, figsize=(6,5), dpi=120)
ax.plot(chunksizes, output_scores)
ax.set(xlim=[0.0,105.0], ylim=[0.5,1.0], xlabel='Size of the chunk, # samples', ylabel='Accuracy', \
       title=r'Classifier: SVM RBF (default C and $\gamma$)')
plt.tight_layout()
plt.show()

# %%
def separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize):

    X_train = []
    X_test = []
    f_train = []
    f_test = []

    mode = 'train'
    for i in range (0, len(labels_allmoments), chunksize):
        _chunksize = chunksize
        if (i + chunksize > len(labels_allmoments)): _chunksize = len(labels_allmoments) - i
        if (mode == 'train'):
            for j in range (0, _chunksize, 1):
                X_train.append(featurevector_allmoments[i+j,:])
                f_train.append(labels_allmoments[i+j])
            mode = 'test'
            continue
        if (mode == 'test'):
            for j in range (0, _chunksize, 1):
                X_test.append(featurevector_allmoments[i+j,:])
                f_test.append(labels_allmoments[i+j])
            mode = 'train'
            continue

    X_train = np.array(X_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    f_train = np.array(f_train, dtype=float)
    f_test = np.array(f_test, dtype=float)
    
    print("The size of the chunk:", chunksize)
    print("Number of positive - negative samples in train: " + str(np.sum(f_train)) + " --- " + str(len(f_train)-np.sum(f_train)))
    print("Number of positive - negative samples in test: " + str(np.sum(f_test)) + " --- " + str(len(f_test)-np.sum(f_test)))
    
    return X_train, X_test, f_train, f_test

output_scores = []
chunksizes = np.arange(2, 102, 2)

for chunksize in chunksizes:
    X_train, X_test, f_train, f_test = separate_chunksizebased(featurevector_allmoments, labels_allmoments, chunksize)
    clf = RandomForestClassifier(max_depth=10, random_state=0)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    output_scores.append(outputclass_analysis(f_test, f_predicted, output_score='accuracy'))
# Out:
# The size of the chunk: 2
# Number of positive - negative samples in train: 197.0 --- 302.0
# Number of positive - negative samples in test: 195.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 179
# TN = 299
# FP = 4
# FN = 16
# Precision = 0.9781420765027322
# Recall = 0.9179487179487179
# Accuracy = 0.9598393574297188
# TSS = 0.9047473978167047
# HSS = 0.9147800195081883
# The size of the chunk: 4
# Number of positive - negative samples in train: 201.0 --- 299.0
# Number of positive - negative samples in test: 191.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 173
# TN = 298
# FP = 8
# FN = 18
# Precision = 0.9558011049723757
# Recall = 0.9057591623036649
# Accuracy = 0.9476861167002012
# TSS = 0.8796153714539917
# HSS = 0.8883551346961345
# The size of the chunk: 6
# Number of positive - negative samples in train: 186.0 --- 313.0
# Number of positive - negative samples in test: 206.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 177
# TN = 286
# FP = 6
# FN = 29
# Precision = 0.9672131147540983
# Recall = 0.8592233009708737
# Accuracy = 0.929718875502008
# TSS = 0.8386753557653943
# HSS = 0.8526950965975356
# The size of the chunk: 8
# Number of positive - negative samples in train: 207.0 --- 294.0
# Number of positive - negative samples in test: 185.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 173
# TN = 283
# FP = 28
# FN = 12
# Precision = 0.8606965174129353
# Recall = 0.9351351351351351
# Accuracy = 0.9193548387096774
# TSS = 0.8451029807942991
# HSS = 0.8305519020207369
# The size of the chunk: 10
# Number of positive - negative samples in train: 180.0 --- 320.0
# Number of positive - negative samples in test: 212.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 179
# TN = 283
# FP = 2
# FN = 33
# Precision = 0.988950276243094
# Recall = 0.8443396226415094
# Accuracy = 0.9295774647887324
# TSS = 0.8373220787818603
# HSS = 0.8533020737579801
# The size of the chunk: 12
# Number of positive - negative samples in train: 190.0 --- 314.0
# Number of positive - negative samples in test: 202.0 --- 291.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 186
# TN = 279
# FP = 12
# FN = 16
# Precision = 0.9393939393939394
# Recall = 0.9207920792079208
# Accuracy = 0.9432048681541582
# TSS = 0.879554965805859
# HSS = 0.882226469182991
# The size of the chunk: 14
# Number of positive - negative samples in train: 183.0 --- 321.0
# Number of positive - negative samples in test: 209.0 --- 284.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 152
# TN = 269
# FP = 15
# FN = 57
# Precision = 0.9101796407185628
# Recall = 0.7272727272727273
# Accuracy = 0.8539553752535497
# TSS = 0.6744558258642765
# HSS = 0.6928402069884564
# The size of the chunk: 16
# Number of positive - negative samples in train: 201.0 --- 300.0
# Number of positive - negative samples in test: 191.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 156
# TN = 263
# FP = 42
# FN = 35
# Precision = 0.7878787878787878
# Recall = 0.8167539267015707
# Accuracy = 0.844758064516129
# TSS = 0.6790490086687837
# HSS = 0.6744297064138848
# The size of the chunk: 18
# Number of positive - negative samples in train: 170.0 --- 334.0
# Number of positive - negative samples in test: 222.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 164
# TN = 253
# FP = 18
# FN = 58
# Precision = 0.9010989010989011
# Recall = 0.7387387387387387
# Accuracy = 0.845841784989858
# TSS = 0.6723180745320967
# HSS = 0.6834510493055321
# The size of the chunk: 20
# Number of positive - negative samples in train: 198.0 --- 302.0
# Number of positive - negative samples in test: 194.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 266
# FP = 37
# FN = 34
# Precision = 0.8121827411167513
# Recall = 0.8247422680412371
# Accuracy = 0.8571428571428571
# TSS = 0.7026300568201149
# HSS = 0.7006811376610598
# The size of the chunk: 22
# Number of positive - negative samples in train: 212.0 --- 294.0
# Number of positive - negative samples in test: 180.0 --- 311.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 168
# TN = 266
# FP = 45
# FN = 12
# Precision = 0.7887323943661971
# Recall = 0.9333333333333333
# Accuracy = 0.8839103869653768
# TSS = 0.7886387995712755
# HSS = 0.7593199349861974
# The size of the chunk: 24
# Number of positive - negative samples in train: 180.0 --- 324.0
# Number of positive - negative samples in test: 212.0 --- 281.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 156
# TN = 253
# FP = 28
# FN = 56
# Precision = 0.8478260869565217
# Recall = 0.7358490566037735
# Accuracy = 0.8296146044624746
# TSS = 0.6362049284898945
# HSS = 0.6466914650377095
# The size of the chunk: 26
# Number of positive - negative samples in train: 204.0 --- 299.0
# Number of positive - negative samples in test: 188.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 183
# TN = 274
# FP = 32
# FN = 5
# Precision = 0.8511627906976744
# Recall = 0.973404255319149
# Accuracy = 0.9251012145748988
# TSS = 0.8688290919204562
# HSS = 0.845418717545373
# The size of the chunk: 28
# Number of positive - negative samples in train: 196.0 --- 308.0
# Number of positive - negative samples in test: 196.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 179
# TN = 265
# FP = 32
# FN = 17
# Precision = 0.8483412322274881
# Recall = 0.9132653061224489
# Accuracy = 0.9006085192697769
# TSS = 0.8055211983783412
# HSS = 0.7951737762741756
# The size of the chunk: 30
# Number of positive - negative samples in train: 211.0 --- 299.0
# Number of positive - negative samples in test: 181.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 132
# TN = 289
# FP = 17
# FN = 49
# Precision = 0.8859060402684564
# Recall = 0.7292817679558011
# Accuracy = 0.864476386036961
# TSS = 0.6737262124002455
# HSS = 0.698966021054209
# The size of the chunk: 32
# Number of positive - negative samples in train: 211.0 --- 301.0
# Number of positive - negative samples in test: 181.0 --- 304.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 144
# TN = 273
# FP = 31
# FN = 37
# Precision = 0.8228571428571428
# Recall = 0.7955801104972375
# Accuracy = 0.8597938144329897
# TSS = 0.6936064262867112
# HSS = 0.6982892690513219
# The size of the chunk: 34
# Number of positive - negative samples in train: 168.0 --- 342.0
# Number of positive - negative samples in test: 224.0 --- 263.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 170
# TN = 234
# FP = 29
# FN = 54
# Precision = 0.8542713567839196
# Recall = 0.7589285714285714
# Accuracy = 0.8295687885010267
# TSS = 0.648662411732754
# HSS = 0.6540749172008319
# The size of the chunk: 36
# Number of positive - negative samples in train: 193.0 --- 311.0
# Number of positive - negative samples in test: 199.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 170
# TN = 253
# FP = 41
# FN = 29
# Precision = 0.8056872037914692
# Recall = 0.8542713567839196
# Accuracy = 0.8580121703853956
# TSS = 0.7148155744709945
# HSS = 0.7079186133116663
# The size of the chunk: 38
# Number of positive - negative samples in train: 197.0 --- 306.0
# Number of positive - negative samples in test: 195.0 --- 299.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 108
# TN = 280
# FP = 19
# FN = 87
# Precision = 0.8503937007874016
# Recall = 0.5538461538461539
# Accuracy = 0.7854251012145749
# TSS = 0.4903010033444816
# HSS = 0.5219558509375741
# The size of the chunk: 40
# Number of positive - negative samples in train: 209.0 --- 308.0
# Number of positive - negative samples in test: 183.0 --- 297.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 159
# TN = 266
# FP = 31
# FN = 24
# Precision = 0.8368421052631579
# Recall = 0.8688524590163934
# Accuracy = 0.8854166666666666
# TSS = 0.7644753546392891
# HSS = 0.7589041095890411
# The size of the chunk: 42
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 176
# TN = 245
# FP = 23
# FN = 49
# Precision = 0.8844221105527639
# Recall = 0.7822222222222223
# Accuracy = 0.8539553752535497
# TSS = 0.6964013266998342
# HSS = 0.7029175942819839
# The size of the chunk: 44
# Number of positive - negative samples in train: 211.0 --- 302.0
# Number of positive - negative samples in test: 181.0 --- 303.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 137
# TN = 217
# FP = 86
# FN = 44
# Precision = 0.6143497757847534
# Recall = 0.7569060773480663
# Accuracy = 0.731404958677686
# TSS = 0.47307769450978243
# HSS = 0.45196411462416164
# The size of the chunk: 46
# Number of positive - negative samples in train: 206.0 --- 300.0
# Number of positive - negative samples in test: 186.0 --- 305.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 121
# TN = 295
# FP = 10
# FN = 65
# Precision = 0.9236641221374046
# Recall = 0.6505376344086021
# Accuracy = 0.8472505091649695
# TSS = 0.6177507491627005
# HSS = 0.6555675068980031
# The size of the chunk: 48
# Number of positive - negative samples in train: 183.0 --- 334.0
# Number of positive - negative samples in test: 209.0 --- 271.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 237
# FP = 34
# FN = 71
# Precision = 0.8023255813953488
# Recall = 0.6602870813397129
# Accuracy = 0.78125
# TSS = 0.5348258267271668
# HSS = 0.5458804872774454
# The size of the chunk: 50
# Number of positive - negative samples in train: 189.0 --- 311.0
# Number of positive - negative samples in test: 203.0 --- 294.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 173
# TN = 239
# FP = 55
# FN = 30
# Precision = 0.7587719298245614
# Recall = 0.8522167487684729
# Accuracy = 0.8289738430583501
# TSS = 0.6651419188365001
# HSS = 0.6527018472693791
# The size of the chunk: 52
# Number of positive - negative samples in train: 224.0 --- 296.0
# Number of positive - negative samples in test: 168.0 --- 309.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 134
# TN = 236
# FP = 73
# FN = 34
# Precision = 0.6473429951690821
# Recall = 0.7976190476190477
# Accuracy = 0.7756813417190775
# TSS = 0.5613730929264911
# HSS = 0.5331357536840372
# The size of the chunk: 54
# Number of positive - negative samples in train: 202.0 --- 309.0
# Number of positive - negative samples in test: 190.0 --- 296.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 154
# TN = 243
# FP = 53
# FN = 36
# Precision = 0.7439613526570048
# Recall = 0.8105263157894737
# Accuracy = 0.8168724279835391
# TSS = 0.6314722617354196
# HSS = 0.6215151992439755
# The size of the chunk: 56
# Number of positive - negative samples in train: 169.0 --- 335.0
# Number of positive - negative samples in test: 223.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 176
# TN = 232
# FP = 38
# FN = 47
# Precision = 0.822429906542056
# Recall = 0.7892376681614349
# Accuracy = 0.8275862068965517
# TSS = 0.6484969274206942
# HSS = 0.6507829362400727
# The size of the chunk: 58
# Number of positive - negative samples in train: 174.0 --- 348.0
# Number of positive - negative samples in test: 218.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 118
# TN = 249
# FP = 8
# FN = 100
# Precision = 0.9365079365079365
# Recall = 0.5412844036697247
# Accuracy = 0.7726315789473684
# TSS = 0.510155999000464
# HSS = 0.5270320106210356
# The size of the chunk: 60
# Number of positive - negative samples in train: 220.0 --- 297.0
# Number of positive - negative samples in test: 172.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 240
# FP = 68
# FN = 12
# Precision = 0.7017543859649122
# Recall = 0.9302325581395349
# Accuracy = 0.8333333333333334
# TSS = 0.7094533373603141
# HSS = 0.661876584953508
# The size of the chunk: 62
# Number of positive - negative samples in train: 249.0 --- 252.0
# Number of positive - negative samples in test: 143.0 --- 353.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 127
# TN = 284
# FP = 69
# FN = 16
# Precision = 0.6479591836734694
# Recall = 0.8881118881118881
# Accuracy = 0.8286290322580645
# TSS = 0.6926444660155708
# HSS = 0.6238669616729713
# The size of the chunk: 64
# Number of positive - negative samples in train: 221.0 --- 291.0
# Number of positive - negative samples in test: 171.0 --- 314.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 150
# TN = 240
# FP = 74
# FN = 21
# Precision = 0.6696428571428571
# Recall = 0.8771929824561403
# Accuracy = 0.8041237113402062
# TSS = 0.641524192647223
# HSS = 0.5992328233319126
# The size of the chunk: 66
# Number of positive - negative samples in train: 184.0 --- 344.0
# Number of positive - negative samples in test: 208.0 --- 261.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 199
# TN = 134
# FP = 127
# FN = 9
# Precision = 0.6104294478527608
# Recall = 0.9567307692307693
# Accuracy = 0.7100213219616205
# TSS = 0.47014073091659303
# HSS = 0.44453540015675347
# The size of the chunk: 68
# Number of positive - negative samples in train: 153.0 --- 368.0
# Number of positive - negative samples in test: 239.0 --- 237.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 207
# FP = 30
# FN = 79
# Precision = 0.8421052631578947
# Recall = 0.6694560669456067
# Accuracy = 0.7710084033613446
# TSS = 0.542873788464594
# HSS = 0.5424045720736612
# The size of the chunk: 70
# Number of positive - negative samples in train: 160.0 --- 347.0
# Number of positive - negative samples in test: 232.0 --- 258.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 114
# TN = 208
# FP = 50
# FN = 118
# Precision = 0.6951219512195121
# Recall = 0.49137931034482757
# Accuracy = 0.6571428571428571
# TSS = 0.29758086073242446
# HSS = 0.3020416468832666
# The size of the chunk: 72
# Number of positive - negative samples in train: 167.0 --- 337.0
# Number of positive - negative samples in test: 225.0 --- 268.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 160
# TN = 223
# FP = 45
# FN = 65
# Precision = 0.7804878048780488
# Recall = 0.7111111111111111
# Accuracy = 0.7768762677484787
# TSS = 0.5432006633499171
# HSS = 0.5471020544513112
# The size of the chunk: 74
# Number of positive - negative samples in train: 183.0 --- 335.0
# Number of positive - negative samples in test: 209.0 --- 270.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 186
# TN = 174
# FP = 96
# FN = 23
# Precision = 0.6595744680851063
# Recall = 0.8899521531100478
# Accuracy = 0.7515657620041754
# TSS = 0.5343965975544922
# HSS = 0.5141118205143504
# The size of the chunk: 76
# Number of positive - negative samples in train: 184.0 --- 348.0
# Number of positive - negative samples in test: 208.0 --- 257.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 146
# TN = 221
# FP = 36
# FN = 62
# Precision = 0.8021978021978022
# Recall = 0.7019230769230769
# Accuracy = 0.789247311827957
# TSS = 0.5618452559114038
# HSS = 0.5686211401200325
# The size of the chunk: 78
# Number of positive - negative samples in train: 209.0 --- 320.0
# Number of positive - negative samples in test: 183.0 --- 285.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 138
# TN = 216
# FP = 69
# FN = 45
# Precision = 0.6666666666666666
# Recall = 0.7540983606557377
# Accuracy = 0.7564102564102564
# TSS = 0.5119930974978429
# HSS = 0.5002529084471421
# The size of the chunk: 80
# Number of positive - negative samples in train: 218.0 --- 299.0
# Number of positive - negative samples in test: 174.0 --- 306.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 126
# TN = 235
# FP = 71
# FN = 48
# Precision = 0.6395939086294417
# Recall = 0.7241379310344828
# Accuracy = 0.7520833333333333
# TSS = 0.4921117872436331
# HSS = 0.4784704722252657
# The size of the chunk: 82
# Number of positive - negative samples in train: 224.0 --- 281.0
# Number of positive - negative samples in test: 168.0 --- 324.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 137
# TN = 238
# FP = 86
# FN = 31
# Precision = 0.6143497757847534
# Recall = 0.8154761904761905
# Accuracy = 0.7621951219512195
# TSS = 0.5500440917107583
# HSS = 0.5098600183917441
# The size of the chunk: 84
# Number of positive - negative samples in train: 221.0 --- 283.0
# Number of positive - negative samples in test: 171.0 --- 322.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 130
# TN = 215
# FP = 107
# FN = 41
# Precision = 0.5485232067510548
# Recall = 0.7602339181286549
# Accuracy = 0.6997971602434077
# TSS = 0.4279357814826922
# HSS = 0.39242234990423847
# The size of the chunk: 86
# Number of positive - negative samples in train: 219.0 --- 297.0
# Number of positive - negative samples in test: 173.0 --- 308.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 62
# TN = 232
# FP = 76
# FN = 111
# Precision = 0.4492753623188406
# Recall = 0.3583815028901734
# Accuracy = 0.6112266112266113
# TSS = 0.11162825613692665
# HSS = 0.11680724252034995
# The size of the chunk: 88
# Number of positive - negative samples in train: 218.0 --- 310.0
# Number of positive - negative samples in test: 174.0 --- 295.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 67
# TN = 216
# FP = 79
# FN = 107
# Precision = 0.4589041095890411
# Recall = 0.3850574712643678
# Accuracy = 0.603411513859275
# TSS = 0.11726086109487627
# HSS = 0.12126279313401564
# The size of the chunk: 90
# Number of positive - negative samples in train: 202.0 --- 338.0
# Number of positive - negative samples in test: 190.0 --- 267.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 113
# TN = 172
# FP = 95
# FN = 77
# Precision = 0.5432692307692307
# Recall = 0.5947368421052631
# Accuracy = 0.6236323851203501
# TSS = 0.23893159865957025
# HSS = 0.23571164653948623
# The size of the chunk: 92
# Number of positive - negative samples in train: 208.0 --- 329.0
# Number of positive - negative samples in test: 184.0 --- 276.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 119
# TN = 195
# FP = 81
# FN = 65
# Precision = 0.595
# Recall = 0.6467391304347826
# Accuracy = 0.6826086956521739
# TSS = 0.35326086956521735
# HSS = 0.3482142857142857
# The size of the chunk: 94
# Number of positive - negative samples in train: 214.0 --- 313.0
# Number of positive - negative samples in test: 178.0 --- 292.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 147
# TN = 175
# FP = 117
# FN = 31
# Precision = 0.5568181818181818
# Recall = 0.8258426966292135
# Accuracy = 0.6851063829787234
# TSS = 0.4251577651223642
# HSS = 0.38851577059671577
# The size of the chunk: 96
# Number of positive - negative samples in train: 229.0 --- 288.0
# Number of positive - negative samples in test: 163.0 --- 317.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 135
# TN = 170
# FP = 147
# FN = 28
# Precision = 0.4787234042553192
# Recall = 0.8282208588957055
# Accuracy = 0.6354166666666666
# TSS = 0.3644984614193648
# HSS = 0.3095966071604695
# The size of the chunk: 98
# Number of positive - negative samples in train: 234.0 --- 273.0
# Number of positive - negative samples in test: 158.0 --- 332.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 133
# TN = 199
# FP = 133
# FN = 25
# Precision = 0.5
# Recall = 0.8417721518987342
# Accuracy = 0.6775510204081633
# TSS = 0.44116974226018
# HSS = 0.37415119963784516
# The size of the chunk: 100
# Number of positive - negative samples in train: 242.0 --- 258.0
# Number of positive - negative samples in test: 150.0 --- 347.0
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 141
# TN = 192
# FP = 155
# FN = 9
# Precision = 0.47635135135135137
# Recall = 0.94
# Accuracy = 0.670020120724346
# TSS = 0.4933141210374639
# HSS = 0.38652135298279416

# %%
im, ax = plt.subplots(1, 1, figsize=(6,5), dpi=120)
ax.plot(chunksizes, output_scores)
ax.set(xlim=[0.0,105.0], ylim=[0.5,1.0], xlabel='Size of the chunk, # samples', ylabel='Accuracy', \
       title=r'Random Forest (depth=2, default)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test 3. Treating the last three simulations as unknowns.

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_moments.npy')
labels_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_labels.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_timep.npy')
print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 997
# Among them unstable (positive) samples: 392

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
print(featurevector_allmoments.shape)
print(labels_allmoments.shape)
# Out:
# (997, 21)
# (997,)

# %%
X_train = featurevector_allmoments[:-80,:]
X_test = featurevector_allmoments[-80:,:]
f_train = labels_allmoments[:-80]
f_test = labels_allmoments[-80:]

# %%
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train, f_train)
f_predicted = clf.predict(X_test)
outputclass_analysis(f_test, f_predicted)
# Out:
# ------------ SUMMARY OF CLASSIFICATION RESULTS ----------------
# TP = 2
# TN = 16
# FP = 62
# FN = 0
# Precision = 0.03125
# Recall = 1.0
# Accuracy = 0.225
# TSS = 0.20512820512820518
# HSS = 0.012738853503184714

# %% [markdown]
# ## Test 4. 10 random train-test pairs.

# %%
featurevector_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_moments.npy')
labels_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_labels.npy')
times_allmoments = np.load('./mldata_vdfmoments/allsimulations.mldata_timep.npy')
print('The total number of data points is: ' + str(len(labels_allmoments)))
print('Among them unstable (positive) samples: ' + str(len(np.where(labels_allmoments == 1)[0])))
# Out:
# The total number of data points is: 997
# Among them unstable (positive) samples: 392

# %%
scaler = StandardScaler()
scaler.fit(featurevector_allmoments)
featurevector_allmoments = scaler.transform(featurevector_allmoments)

# %%
def outputclass_analysis_scorereturn(test_labels, predicted_labels):
    tn, fp, fn, tp = confusion_matrix(test_labels, predicted_labels).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    acc = (tp+tn)/(tp+fn+fp+tn)
    tss = tp/(tp+fn) - fp/(fp+tn)
    hss = 2*(tp*tn - fp*fn)/((tp+fn)*(fn+tn) + (tp+fp)*(fp+tn))
    return tp, tn, fp, fn, acc, tss

# %%
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i in range (0, 10, 1):
    X_train, X_test, f_train, f_test = \
      train_test_split(featurevector_allmoments, labels_allmoments, test_size=0.33, random_state=i)
    clf = KNeighborsClassifier(n_neighbors=5)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# TP = 104.7+/-7.184010022264724
# TN = 189.2+/-6.029925372672534
# FP = 11.7+/-3.3778691508109073
# FN = 24.4+/-6.636264009214823
# Acc = 0.8906060606060606+/-0.015945844990209537
# TSS = 0.7540277365551376+/-0.039251367239285476

# %%
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i in range (0, 10, 1):
    X_train, X_test, f_train, f_test = \
      train_test_split(featurevector_allmoments, labels_allmoments, test_size=0.33, random_state=i)
    clf = SVC(kernel='rbf', class_weight='balanced')
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# TP = 110.7+/-6.664082832618455
# TN = 168.5+/-7.826237921249264
# FP = 32.4+/-6.755738301621815
# FN = 18.4+/-4.2708313008125245
# Acc = 0.8460606060606061+/-0.0240064270549556
# TSS = 0.6971275951085416+/-0.046400836802194353

# %%
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i in range (0, 10, 1):
    X_train, X_test, f_train, f_test = \
      train_test_split(featurevector_allmoments, labels_allmoments, test_size=0.33, random_state=i)
    clf = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=10000, tol=1e-6)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# TP = 113.3+/-7.253275122315436
# TN = 189.2+/-7.704544113703289
# FP = 11.7+/-1.8466185312619388
# FN = 15.8+/-4.833218389437829
# Acc = 0.9166666666666666+/-0.01616319436738739
# TSS = 0.8199078243589752+/-0.036507940230552975

# %%
tp = np.zeros([10], dtype=int)
tn = np.zeros([10], dtype=int)
fp = np.zeros([10], dtype=int)
fn = np.zeros([10], dtype=int)
acc = np.zeros([10], dtype=float)
tss = np.zeros([10], dtype=float)

for i in range (0, 10, 1):
    X_train, X_test, f_train, f_test = \
      train_test_split(featurevector_allmoments, labels_allmoments, test_size=0.33, random_state=i)
    clf = RandomForestClassifier(max_depth=10, random_state=0)
    clf.fit(X_train, f_train)
    f_predicted = clf.predict(X_test)
    tp[i], tn[i], fp[i], fn[i], acc[i], tss[i] = outputclass_analysis_scorereturn(f_test, f_predicted)
    
print("TP = " + str(np.mean(tp)) + "+/-" + str(np.std(tp)))
print("TN = " + str(np.mean(tn)) + "+/-" + str(np.std(tn)))
print("FP = " + str(np.mean(fp)) + "+/-" + str(np.std(fp)))
print("FN = " + str(np.mean(fn)) + "+/-" + str(np.std(fn)))
print("Acc = " + str(np.mean(acc)) + "+/-" + str(np.std(acc)))
print("TSS = " + str(np.mean(tss)) + "+/-" + str(np.std(tss)))
# Out:
# TP = 120.1+/-7.217340230306452
# TN = 197.0+/-7.483314773547883
# FP = 3.9+/-2.808914381037628
# FN = 9.0+/-3.4351128074635335
# Acc = 0.9609090909090907+/-0.004781737526684706
# TSS = 0.9113873763638886+/-0.014968899816957225
