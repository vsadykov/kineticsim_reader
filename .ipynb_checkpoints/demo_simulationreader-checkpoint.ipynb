# %% [markdown]
# ### Loading the modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import kineticsim_reader as kr
import pickle
import os
# Out:
# C:\Users\Slava\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# ### Setting up a path to the simulation file and the number of species to include

# %%
# Please repalce the simulation file path with the path on your machine
simulationfile = r'C:\Users\Slava\Google Drive\[Projects]\[yyyy] [Project] PSP ML\particles.d11_pv2av2_rdna0.03375_128x3_iden0eps1e-4_dx0.75_t6000'
# The number of species for the selected simulation
kspi = 4
# Indexes corresponding to protons and alpha particle species
kspi_pr = [0,1]
kspi_he = [2,3]

# %% [markdown]
# ### Working with the simulation

# %% [markdown]
# Displaying information about the simulations. This routine takes the filename and the number of species as an input and returns the header parameters and the frame record #, iteration #, and timing in gyroperiods.

# %%
header = kr.show_fileinfo(simulationfile, kspi=kspi)
# Out:
# Header information:
# HEADER[0]:          dt: 0.02
# HEADER[1]:          dx: 0.75
# HEADER[2]:          dy: 0.75
# HEADER[3]:       itmax: 300006.0
# HEADER[4]:        ifld: 2.0
# HEADER[5]:      betaen: 0.429
# HEADER[6]:         nis: 4.0
# HEADER[7]:          nx: 128.0
# HEADER[8]:          ny: 128.0
# HEADER[9]:         npt: 8388608.0
# HEADER[10]:    ifields: 50.0
# HEADER[11]: iparticles: 2000.0
# HEADER[12]:    ienergy: 50.0
# HEADER[13]:    ifilter: 1250.0
# HEADER[14]:        bx0: 1.0
# HEADER[15]:        by0: 0.0
# HEADER[16]:        bz0: 0.0
# HEADER[17]:      icont: 1.0
# HEADER[18]:      xlres: 0.0
# Frame record in file: 1 , Frame number: 226001.0 , Frame timing: 4520.02
# Frame record in file: 2 , Frame number: 228001.0 , Frame timing: 4560.02
# Frame record in file: 3 , Frame number: 230001.0 , Frame timing: 4600.02
# Frame record in file: 4 , Frame number: 232001.0 , Frame timing: 4640.02
# Frame record in file: 5 , Frame number: 234001.0 , Frame timing: 4680.02
# Frame record in file: 6 , Frame number: 236001.0 , Frame timing: 4720.02
# Frame record in file: 7 , Frame number: 238001.0 , Frame timing: 4760.02
# Frame record in file: 8 , Frame number: 240001.0 , Frame timing: 4800.02
# Frame record in file: 9 , Frame number: 242001.0 , Frame timing: 4840.02
# Frame record in file: 10 , Frame number: 244001.0 , Frame timing: 4880.02
# Frame record in file: 11 , Frame number: 246001.0 , Frame timing: 4920.02
# Frame record in file: 12 , Frame number: 248001.0 , Frame timing: 4960.02
# Frame record in file: 13 , Frame number: 250001.0 , Frame timing: 5000.02
# Frame record in file: 14 , Frame number: 252001.0 , Frame timing: 5040.02
# Frame record in file: 15 , Frame number: 254001.0 , Frame timing: 5080.02
# Frame record in file: 16 , Frame number: 256001.0 , Frame timing: 5120.02
# Frame record in file: 17 , Frame number: 258001.0 , Frame timing: 5160.02
# Frame record in file: 18 , Frame number: 260001.0 , Frame timing: 5200.02
# Frame record in file: 19 , Frame number: 262001.0 , Frame timing: 5240.02
# Frame record in file: 20 , Frame number: 264001.0 , Frame timing: 5280.02
# Frame record in file: 21 , Frame number: 266001.0 , Frame timing: 5320.02
# Frame record in file: 22 , Frame number: 268001.0 , Frame timing: 5360.02
# Frame record in file: 23 , Frame number: 270001.0 , Frame timing: 5400.02
# Frame record in file: 24 , Frame number: 272001.0 , Frame timing: 5440.02
# Frame record in file: 25 , Frame number: 274001.0 , Frame timing: 5480.02
# Frame record in file: 26 , Frame number: 276001.0 , Frame timing: 5520.02
# Frame record in file: 27 , Frame number: 278001.0 , Frame timing: 5560.02
# Frame record in file: 28 , Frame number: 280001.0 , Frame timing: 5600.02
# Frame record in file: 29 , Frame number: 282001.0 , Frame timing: 5640.02
# Frame record in file: 30 , Frame number: 284001.0 , Frame timing: 5680.02
# Frame record in file: 31 , Frame number: 286001.0 , Frame timing: 5720.02
# Frame record in file: 32 , Frame number: 288001.0 , Frame timing: 5760.02
# Frame record in file: 33 , Frame number: 290001.0 , Frame timing: 5800.02
# Frame record in file: 34 , Frame number: 292001.0 , Frame timing: 5840.02
# Frame record in file: 35 , Frame number: 294001.0 , Frame timing: 5880.02
# Frame record in file: 36 , Frame number: 296001.0 , Frame timing: 5920.02
# Frame record in file: 37 , Frame number: 298001.0 , Frame timing: 5960.02
# Frame record in file: 38 , Frame number: 300001.0 , Frame timing: 6000.02
# Total number of frames: 38

# %% [markdown]
# Reading of the selected frame in the simulations. Based on the information in the header output, one can selecte the frame record # to read (in our case it will be the frame # 10) and return the timing and distribution variables.
#
# The routine takes the filename, the record # in file, and the number of species as an input. It returns the frame number, time in gyroperiods, and position (xp, yp) and velocity (vxp, vyp, vzp) distributions as arrays.

# %%
timfrm, timep, xp, yp, vxp, vyp, vzp = kr.return_selectedframe(simulationfile, 10, kspi=kspi)

# %% [markdown]
# Generating the histogram (VDF) for the simulations. The inputs are the velocity arrays (x and y for this case), the resolution of the VDF in Alfven speeds (0.05 VA for this case), and the starting and ending number of species. For this example, istart=0 and iend=2, which means that the histogram will be constructed for the species 0 and 1 combined. One can change it to the 0 and 1 to visualize to the core only.
#
# The next line visualizes the VDF. The histogram limits are currently set to +/-3.5vA (for ML purposes), however, the customized limits will be available in future. There is an option to save the VDF to the file as an image, please check 'kineticsim_reader.py' for details.

# %%
hist, vx_edges, vy_edges = kr.generate_histogram(vxp, vyp, resl=0.02, xlim=[-1.5,1.5], ylim=[-1.5,1.5], kspi_indexes = kspi_pr)
kr.visualize_histogram(hist, vx_edges, vy_edges, 'Proton VDF', to_image = False)

hist, vx_edges, vy_edges = kr.generate_histogram(vxp, vyp, resl=0.05, xlim=[-2.0,2.0], ylim=[-2.0,2.0], kspi_indexes = kspi_he)
kr.visualize_histogram(hist, vx_edges, vy_edges, 'He VDF', to_image = False)

# %% [markdown]
# Lastly, we can compute the anisotropy and moments for this VDF

# %%
anisotropy_p, moments_p = kr.calculate_anisotropy_moments(vxp, vyp, vzp, kspi_indexes = kspi_pr)
anisotropy_he, moments_he = kr.calculate_anisotropy_moments(vxp, vyp, vzp, kspi_indexes = kspi_he)
print("Proton anisotropy:", anisotropy_p)
print("He anisotropy:", anisotropy_he)
print("Proton moments:", moments_p)
# Out:
# Proton anisotropy: 0.7843663229196386
# He anisotropy: 0.6121669890333552
# Proton moments: [[ 3.50899339e-01 -5.47791249e-04  5.22112357e-04]
#  [ 6.30077839e-01  4.93776441e-01  4.94647235e-01]
#  [ 8.31495076e-02 -5.66887145e-04 -1.69139574e-04]
#  [ 1.09092653e+00  9.00010943e-01  9.02214646e-01]]

# %% [markdown]
# The moments are 4x3 matrix, where:
# - the dimension 3 corresponds to x, y, and z components
# - the dimension 4 corresponds to the mean velocities and 2-4 degree moments centered at the mean velocity

# %% [markdown]
# ### Plotting temperatures (in the units of $<(V/V_{A})^{2}>$) and anisotropies as functinos of time

# %%
anisotropies_p, moments_p, anisotropies_he, moments_he, timing = kr.calculate_anisotropies_moments_selectedframes(\
                                                                 simulationfile, framestart = 0, frameend = 5, kspi=kspi, \
                                                                 kspi_indexes_protons = kspi_pr, kspi_indexes_he = kspi_he)
# Out:
# Reading the file...
# MOMENTS READ FOR FRAME: 1
# MOMENTS READ FOR FRAME: 2
# MOMENTS READ FOR FRAME: 3
# MOMENTS READ FOR FRAME: 4
# MOMENTS READ FOR FRAME: 5

# %%
matplotlib.rcParams.update({'font.size':12})
im, ax = plt.subplots(1, 3, figsize = (15, 5), dpi=150)

ax[0].plot(timing, moments_p[:,1,0])
ax[0].set(xlim=[timing[0],timing[-1]], xlabel=r'Time, $\Omega{}_{p}^{-1}$', ylabel=r'T$_{||}$, $<(V/V_{A})^{2}>$')

ax[1].plot(timing, moments_p[:,1,1])
ax[1].set(xlim=[timing[0],timing[-1]], xlabel=r'Time, $\Omega{}_{p}^{-1}$', ylabel=r'T$_{\perp}$, $<(V/V_{A})^{2}>$')

ax[2].plot(timing, anisotropies_p)
ax[2].set(xlim=[timing[0],timing[-1]], xlabel=r'Time, $\Omega{}_{p}^{-1}$', ylabel=r'T anisotropy')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing the fields file reader

# %%
# Please repalce the simulation file path with the path on your machine
fieldsfile = r'C:\Users\Slava\Google Drive\[Projects]\[yyyy] [Project] PSP ML\fields.d10_E11Ap4.3Aa1.6Vd0.32'
# The number of species for the selected simulation
kspi = 2
# Indexes corresponding to protons and alpha particle species
kspi_pr = [0]
kspi_he = [1]

# %%
dx, dy, tim, bx, by, bz, ex, ey, ez, rvxh, rvyh, rvzh, rdnh, tpal, tper, me_perp, me_tot = \
    kr.read_fieldsfile(fieldsfile, kspi=kspi)

# %%
im, ax = plt.subplots(1, 1, figsize=(7,5), dpi=120)
ax.plot(tim[:,1],me_perp)
ax.set(xlabel=r'Time, $\Omega{}_{p}^{-1}$', ylabel='Perpendicular B energy, AU')
plt.tight_layout()
plt.show()

# %%
rdnh.shape
# Out:
# (481, 256, 256, 2)

# %%
print()
